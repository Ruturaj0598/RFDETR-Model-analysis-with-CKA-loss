# %%
import os

os.environ["ROBOFLOW_API_KEY"] = "J1oKKy8ww5yYkJGO3YUZ"

# %%
import numpy as np
import supervision as sv
import json
import os
from PIL import Image
import supervision as sv
from rfdetr import RFDETRBase
import cv2
import matplotlib.pyplot as plt
from rfdetr.util.coco_classes import COCO_CLASSES

# %%
DATASET_NAME = "aicast_dataset"

# Define your dataset paths
DATASET_ROOT = "D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR"

# Train paths
train_dir_images = os.path.join(DATASET_ROOT, "AlCastDetection-20251015T171832Z-1-001\\AlCastDetection\\train\\images")
train_dir_labels = os.path.join(DATASET_ROOT, "AlCastDetection-20251015T171832Z-1-001\\AlCastDetection\\train\\labels")  # YOLO format labels
output_train_dir = os.path.join(DATASET_ROOT, "AlCastDetection-20251015T171832Z-1-001\\AlCastDetection\\train")

# Validation paths
valid_dir_images = os.path.join(DATASET_ROOT, "AlCastDetection-20251015T171832Z-1-001\\AlCastDetection\\valid\\images")
valid_dir_labels = os.path.join(DATASET_ROOT, "AlCastDetection-20251015T171832Z-1-001\\AlCastDetection\\valid\\labels")
output_valid_dir = os.path.join(DATASET_ROOT, "AlCastDetection-20251015T171832Z-1-001\\AlCastDetection\\valid")

# Test paths
test_dir_images = os.path.join(DATASET_ROOT, "AlCastDetection-20251015T171832Z-1-001\\AlCastDetection\\test\\images")
test_dir_labels = os.path.join(DATASET_ROOT, "AlCastDetection-20251015T171832Z-1-001\\AlCastDetection\\test\\labels")
output_test_dir = os.path.join(DATASET_ROOT, "AlCastDetection-20251015T171832Z-1-001\\AlCastDetection\\test")

# %%
# Define categories for the aquatic dataset
categories = [
    {"id": 0, "name": 'Gas-holes', "supercategory": "Gas-holes"}, 
    {"id": 1, "name": 'shrinkage', "supercategory": "none"}
]
print("Categories defined:")
for cat in categories:
    print(f"  ID {cat['id']}: {cat['name']}")
# Out:
# Categories defined:
#   ID 0: Gas-holes
#   ID 1: shrinkage

# %%
def convert_yolo_to_coco(images_dir, labels_dir, output_dir, categories):
    """
    Convert YOLO format annotations to COCO format
    
    Args:
        images_dir: Directory containing images
        labels_dir: Directory containing YOLO format labels (.txt files)
        output_dir: Directory to save COCO format annotations
        categories: List of category dictionaries
    """
    # Create the COCO format schema
    coco_dataset = {
        "info": {},
        "licenses": [],
        "categories": categories,
        "images": [],
        "annotations": [],
    }
    
    annotation_id = 0
    image_id_counter = 0
    
    # Iterate through all images in the directory
    for image_file in os.listdir(images_dir):
        if not image_file.lower().endswith(('.jpg', '.jpeg', '.png')):
            continue
            
        image_path = os.path.join(images_dir, image_file)
        
        # Open image to get dimensions
        try:
            image = Image.open(image_path)
            width, height = image.size
        except Exception as e:
            print(f"Error opening image {image_file}: {e}")
            continue
        
        image_id = image_id_counter
        
        # Create image dictionary
        image_dict = {
            "id": image_id,
            "width": width,
            "height": height,
            "file_name": image_file,
        }
        
        coco_dataset["images"].append(image_dict)
        
        # Read corresponding YOLO annotation file
        label_file = os.path.splitext(image_file)[0] + ".txt"
        label_path = os.path.join(labels_dir, label_file)
        
        if os.path.exists(label_path):
            try:
                with open(label_path, 'r') as f:
                    annotations = f.readlines()
                
                for ann in annotations:
                    parts = ann.strip().split()
                    if len(parts) < 5:
                        continue
                        
                    category_id = int(parts[0])
                    x, y, w, h = map(float, parts[1:5])
                    
                    # Convert YOLO format (normalized center coordinates) to COCO format (absolute corner coordinates)
                    x_min = int((x - w/2) * width)
                    y_min = int((y - h/2) * height)
                    x_max = int((x + w/2) * width)
                    y_max = int((y + h/2) * height)
                    
                    bbox_width = x_max - x_min
                    bbox_height = y_max - y_min
                    
                    # Create annotation dictionary
                    ann_dict = {
                        "id": annotation_id,
                        "image_id": image_id,
                        "category_id": category_id,
                        "bbox": [x_min, y_min, bbox_width, bbox_height],
                        "area": bbox_height * bbox_width,
                        "iscrowd": 0,
                    }
                    
                    coco_dataset["annotations"].append(ann_dict)
                    annotation_id += 1
            except Exception as e:
                print(f"Error processing label file {label_file}: {e}")
        
        image_id_counter += 1
    
    # Save COCO format annotations
    output_file = os.path.join(output_dir, '_annotations.coco.json')
    with open(output_file, 'w') as f:
        json.dump(coco_dataset, f, indent=2)
    
    print(f"Converted {image_id_counter} images with {annotation_id} annotations")
    print(f"Saved to: {output_file}")
    return coco_dataset

print("Conversion function defined successfully!")
# Out:
# Conversion function defined successfully!

# %%
# Convert training set
print("Converting training set...")
train_coco = convert_yolo_to_coco(
    train_dir_images, 
    train_dir_labels, 
    output_train_dir, 
    categories
)

# Convert validation set
print("\nConverting validation set...")
valid_coco = convert_yolo_to_coco(
    valid_dir_images, 
    valid_dir_labels, 
    output_valid_dir, 
    categories
)

# Convert test set
print("\nConverting test set...")
test_coco = convert_yolo_to_coco(
    test_dir_images, 
    test_dir_labels, 
    output_test_dir, 
    categories
)

print("\n✅ All conversions completed!")
# Out:
# Converting training set...
# Converted 2427 images with 4094 annotations
# Saved to: D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\AlCastDetection-20251015T171832Z-1-001\AlCastDetection\train\_annotations.coco.json
#
# Converting validation set...
# Converted 681 images with 1127 annotations
# Saved to: D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\AlCastDetection-20251015T171832Z-1-001\AlCastDetection\valid\_annotations.coco.json
#
# Converting test set...
# Converted 346 images with 588 annotations
# Saved to: D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\AlCastDetection-20251015T171832Z-1-001\AlCastDetection\test\_annotations.coco.json
#
# ✅ All conversions completed!

# %%
import shutil

def copy_images(source_dir, target_dir):
    """Copy images from source to target directory"""
    os.makedirs(target_dir, exist_ok=True)
    for img_file in os.listdir(source_dir):
        if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
            shutil.copy2(
                os.path.join(source_dir, img_file),
                os.path.join(target_dir, img_file)
            )
    print(f"Copied images from {source_dir} to {target_dir}")

# Copy images to COCO format directories
copy_images(train_dir_images, output_train_dir)
copy_images(valid_dir_images, output_valid_dir)
copy_images(test_dir_images, output_test_dir)

print("✅ Image copying completed!")
# Out:
# Copied images from D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\AlCastDetection-20251015T171832Z-1-001\AlCastDetection\train\images to D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\AlCastDetection-20251015T171832Z-1-001\AlCastDetection\train
# Copied images from D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\AlCastDetection-20251015T171832Z-1-001\AlCastDetection\valid\images to D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\AlCastDetection-20251015T171832Z-1-001\AlCastDetection\valid
# Copied images from D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\AlCastDetection-20251015T171832Z-1-001\AlCastDetection\test\images to D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\AlCastDetection-20251015T171832Z-1-001\AlCastDetection\test
# ✅ Image copying completed!

# %%
model = RFDETRBase()

DATASET_DIR = "D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\AlCastDetection-20251015T171832Z-1-001\\AlCastDetection"
OUTPUT_DIR = "D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\aicast_output"
EPOCHS = 50
BATCH_SIZE = 4  # Adjust based on GPU memory (T4: 4, A100: 16)
GRAD_ACCUM_STEPS = 16  # Keep total batch size = batch_size * grad_accum_steps = 16
LEARNING_RATE = 1e-4

# Create output directory
os.makedirs(OUTPUT_DIR, exist_ok=True)

# History callback to track metrics
history = []

def callback_on_epoch_end(data):
    """Callback function to store training metrics"""
    history.append(data)
    print(f"Epoch {data.get('epoch', 0)}: Train Loss = {data.get('train_loss', 0):.4f}, "
          f"Val Loss = {data.get('test_loss', 0):.4f}, mAP = {data.get('test_map', 0):.4f}")

# Register callback
model.callbacks["on_fit_epoch_end"].append(callback_on_epoch_end)

print("Model initialized and ready for training!")
print(f"Dataset: {DATASET_DIR}")
print(f"Output: {OUTPUT_DIR}")
print(f"Epochs: {EPOCHS}, Batch Size: {BATCH_SIZE}, Grad Accum: {GRAD_ACCUM_STEPS}")

model.train(
    dataset_dir=DATASET_DIR,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    grad_accum_steps=GRAD_ACCUM_STEPS,
    lr=LEARNING_RATE,
    output_dir=OUTPUT_DIR,
    use_ema=True,  # Use Exponential Moving Average for better generalization
    tensorboard=False,  # Set to True if you want TensorBoard logging
    early_stopping=True,  # Enable early stopping
    early_stopping_patience=10,  # Stop if no improvement for 10 epochs
    amp=False,  # **CRITICAL: Disable AMP for CPU training**
    device='cpu',  # Explicitly set device to CPU
    num_workers=0,  # Set to 0 for CPU to avoid multiprocessing issues
    multi_scale=False,  # Disable multi-scale training to avoid inference tensors error
    resolution=448,
)
# Out:
# Loading pretrain weights
# Model initialized and ready for training!
# Dataset: D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\AlCastDetection-20251015T171832Z-1-001\AlCastDetection
# Output: D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\aicast_output
# Epochs: 50, Batch Size: 4, Grad Accum: 16
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=2, grad_accum_steps=16, amp=False, lr=0.0001, lr_encoder=0.00015, batch_size=4, weight_decay=0.0001, epochs=50, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-base.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\AlCastDetection-20251015T171832Z-1-001\\AlCastDetection', square_resize_div_64=True, output_dir='D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\aicast_output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=0, device='cpu', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=448, use_cls_token=False, multi_scale=False, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0.0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=14, num_windows=4, positional_encoding_size=37, mask_downsample_ratio=4, tensorboard=False, wandb=False, project=None, run=None, class_names=['Gas-holes'], run_test=True, segmentation_head=False, distributed=False)
# number of params: 31854308
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  16
# Total batch size:  64
# LENGTH OF DATA LOADER: 37
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:3638.)
# Epoch: [0]  [ 0/37]  eta: 1:24:49  lr: 0.000100  class_error: 100.00  loss: 15.5065 (15.5065)  loss_ce: 0.4219 (0.4219)  loss_bbox: 1.3747 (1.3747)  loss_giou: 1.6562 (1.6562)  loss_ce_0: 0.3868 (0.3868)  loss_bbox_0: 2.3979 (2.3979)  loss_giou_0: 1.5011 (1.5011)  loss_ce_1: 0.3937 (0.3937)  loss_bbox_1: 1.3768 (1.3768)  loss_giou_1: 1.6469 (1.6469)  loss_ce_enc: 0.3607 (0.3607)  loss_bbox_enc: 2.3609 (2.3609)  loss_giou_enc: 1.6289 (1.6289)  loss_ce_unscaled: 0.4219 (0.4219)  class_error_unscaled: 100.0000 (100.0000)  loss_bbox_unscaled: 0.2749 (0.2749)  loss_giou_unscaled: 0.8281 (0.8281)  cardinality_error_unscaled: 1.2500 (1.2500)  loss_ce_0_unscaled: 0.3868 (0.3868)  loss_bbox_0_unscaled: 0.4796 (0.4796)  loss_giou_0_unscaled: 0.7505 (0.7505)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.3937 (0.3937)  loss_bbox_1_unscaled: 0.2754 (0.2754)  loss_giou_1_unscaled: 0.8234 (0.8234)  cardinality_error_1_unscaled: 4.2500 (4.2500)  loss_ce_enc_unscaled: 0.3607 (0.3607)  loss_bbox_enc_unscaled: 0.4722 (0.4722)  loss_giou_enc_unscaled: 0.8144 (0.8144)  cardinality_error_enc_unscaled: 1.5000 (1.5000)  time: 137.5632  data: 1.7627
# Epoch: [0]  [10/37]  eta: 0:56:56  lr: 0.000100  class_error: 50.00  loss: 10.3642 (10.5549)  loss_ce: 0.6266 (0.6768)  loss_bbox: 0.3363 (0.4635)  loss_giou: 1.2898 (1.3420)  loss_ce_0: 0.6546 (0.6366)  loss_bbox_0: 0.3713 (0.6426)  loss_giou_0: 1.3263 (1.3995)  loss_ce_1: 0.6029 (0.6388)  loss_bbox_1: 0.3756 (0.4995)  loss_giou_1: 1.5271 (1.4202)  loss_ce_enc: 0.6463 (0.6028)  loss_bbox_enc: 0.4746 (0.7068)  loss_giou_enc: 1.6164 (1.5260)  loss_ce_unscaled: 0.6266 (0.6768)  class_error_unscaled: 40.0000 (42.8139)  loss_bbox_unscaled: 0.0673 (0.0927)  loss_giou_unscaled: 0.6449 (0.6710)  cardinality_error_unscaled: 1.2500 (1.5909)  loss_ce_0_unscaled: 0.6546 (0.6366)  loss_bbox_0_unscaled: 0.0743 (0.1285)  loss_giou_0_unscaled: 0.6631 (0.6997)  cardinality_error_0_unscaled: 1.2500 (1.5455)  loss_ce_1_unscaled: 0.6029 (0.6388)  loss_bbox_1_unscaled: 0.0751 (0.0999)  loss_giou_1_unscaled: 0.7636 (0.7101)  cardinality_error_1_unscaled: 1.2500 (3.0909)  loss_ce_enc_unscaled: 0.6463 (0.6028)  loss_bbox_enc_unscaled: 0.0949 (0.1414)  loss_giou_enc_unscaled: 0.8082 (0.7630)  cardinality_error_enc_unscaled: 2.0000 (42.9318)  time: 126.5265  data: 1.4556
# Epoch: [0]  [20/37]  eta: 0:36:43  lr: 0.000100  class_error: 12.50  loss: 8.7065 (9.5474)  loss_ce: 0.8134 (0.7617)  loss_bbox: 0.2853 (0.3556)  loss_giou: 1.0703 (1.1815)  loss_ce_0: 0.7850 (0.7405)  loss_bbox_0: 0.2798 (0.4525)  loss_giou_0: 1.1391 (1.2223)  loss_ce_1: 0.8036 (0.7439)  loss_bbox_1: 0.2646 (0.3710)  loss_giou_1: 1.0666 (1.2178)  loss_ce_enc: 0.7720 (0.7108)  loss_bbox_enc: 0.2840 (0.4880)  loss_giou_enc: 1.1417 (1.3018)  loss_ce_unscaled: 0.8134 (0.7617)  class_error_unscaled: 33.3333 (33.0880)  loss_bbox_unscaled: 0.0571 (0.0711)  loss_giou_unscaled: 0.5352 (0.5907)  cardinality_error_unscaled: 1.5000 (1.7738)  loss_ce_0_unscaled: 0.7850 (0.7405)  loss_bbox_0_unscaled: 0.0560 (0.0905)  loss_giou_0_unscaled: 0.5695 (0.6112)  cardinality_error_0_unscaled: 1.5000 (1.7500)  loss_ce_1_unscaled: 0.8036 (0.7439)  loss_bbox_1_unscaled: 0.0529 (0.0742)  loss_giou_1_unscaled: 0.5333 (0.6089)  cardinality_error_1_unscaled: 1.5000 (2.5595)  loss_ce_enc_unscaled: 0.7720 (0.7108)  loss_bbox_enc_unscaled: 0.0568 (0.0976)  loss_giou_enc_unscaled: 0.5708 (0.6509)  cardinality_error_enc_unscaled: 2.0000 (23.4286)  time: 129.2032  data: 1.4464
# Epoch: [0]  [30/37]  eta: 0:14:57  lr: 0.000100  class_error: 40.00  loss: 7.9202 (8.9930)  loss_ce: 0.8490 (0.8013)  loss_bbox: 0.1772 (0.2944)  loss_giou: 0.9225 (1.0944)  loss_ce_0: 0.8795 (0.7905)  loss_bbox_0: 0.2018 (0.3620)  loss_giou_0: 0.9221 (1.1208)  loss_ce_1: 0.8738 (0.7896)  loss_bbox_1: 0.1794 (0.3032)  loss_giou_1: 0.9583 (1.1183)  loss_ce_enc: 0.8563 (0.7576)  loss_bbox_enc: 0.2181 (0.3846)  loss_giou_enc: 0.9224 (1.1764)  loss_ce_unscaled: 0.8490 (0.8013)  class_error_unscaled: 33.3333 (37.6254)  loss_bbox_unscaled: 0.0354 (0.0589)  loss_giou_unscaled: 0.4613 (0.5472)  cardinality_error_unscaled: 3.5000 (168.6613)  loss_ce_0_unscaled: 0.8795 (0.7905)  loss_bbox_0_unscaled: 0.0404 (0.0724)  loss_giou_0_unscaled: 0.4611 (0.5604)  cardinality_error_0_unscaled: 2.0000 (5.8387)  loss_ce_1_unscaled: 0.8738 (0.7896)  loss_bbox_1_unscaled: 0.0359 (0.0606)  loss_giou_1_unscaled: 0.4792 (0.5592)  cardinality_error_1_unscaled: 2.5000 (30.8629)  loss_ce_enc_unscaled: 0.8563 (0.7576)  loss_bbox_enc_unscaled: 0.0436 (0.0769)  loss_giou_enc_unscaled: 0.4612 (0.5882)  cardinality_error_enc_unscaled: 1.5000 (16.3629)  time: 129.2190  data: 1.4792
# Epoch: [0]  [36/37]  eta: 0:02:07  lr: 0.000100  class_error: 11.11  loss: 7.8610 (8.8000)  loss_ce: 0.8980 (0.8234)  loss_bbox: 0.1559 (0.2736)  loss_giou: 0.8513 (1.0573)  loss_ce_0: 0.9251 (0.8172)  loss_bbox_0: 0.1481 (0.3285)  loss_giou_0: 0.8440 (1.0737)  loss_ce_1: 0.9020 (0.8126)  loss_bbox_1: 0.1566 (0.2817)  loss_giou_1: 0.8508 (1.0759)  loss_ce_enc: 0.8847 (0.7808)  loss_bbox_enc: 0.1430 (0.3489)  loss_giou_enc: 0.8930 (1.1265)  loss_ce_unscaled: 0.8980 (0.8234)  class_error_unscaled: 33.3333 (34.2567)  loss_bbox_unscaled: 0.0312 (0.0547)  loss_giou_unscaled: 0.4256 (0.5286)  cardinality_error_unscaled: 562.2500 (611.9054)  loss_ce_0_unscaled: 0.9251 (0.8172)  loss_bbox_0_unscaled: 0.0296 (0.0657)  loss_giou_0_unscaled: 0.4220 (0.5368)  cardinality_error_0_unscaled: 2.2500 (178.4932)  loss_ce_1_unscaled: 0.9020 (0.8126)  loss_bbox_1_unscaled: 0.0313 (0.0563)  loss_giou_1_unscaled: 0.4254 (0.5380)  cardinality_error_1_unscaled: 19.0000 (388.5338)  loss_ce_enc_unscaled: 0.8847 (0.7808)  loss_bbox_enc_unscaled: 0.0286 (0.0698)  loss_giou_enc_unscaled: 0.4465 (0.5632)  cardinality_error_enc_unscaled: 1.2500 (13.9595)  time: 125.4750  data: 1.4538
# Epoch: [0] Total time: 1:18:40 (127.5747 s / it)
# Averaged stats: lr: 0.000100  class_error: 11.11  loss: 7.8610 (8.8000)  loss_ce: 0.8980 (0.8234)  loss_bbox: 0.1559 (0.2736)  loss_giou: 0.8513 (1.0573)  loss_ce_0: 0.9251 (0.8172)  loss_bbox_0: 0.1481 (0.3285)  loss_giou_0: 0.8440 (1.0737)  loss_ce_1: 0.9020 (0.8126)  loss_bbox_1: 0.1566 (0.2817)  loss_giou_1: 0.8508 (1.0759)  loss_ce_enc: 0.8847 (0.7808)  loss_bbox_enc: 0.1430 (0.3489)  loss_giou_enc: 0.8930 (1.1265)  loss_ce_unscaled: 0.8980 (0.8234)  class_error_unscaled: 33.3333 (34.2567)  loss_bbox_unscaled: 0.0312 (0.0547)  loss_giou_unscaled: 0.4256 (0.5286)  cardinality_error_unscaled: 562.2500 (611.9054)  loss_ce_0_unscaled: 0.9251 (0.8172)  loss_bbox_0_unscaled: 0.0296 (0.0657)  loss_giou_0_unscaled: 0.4220 (0.5368)  cardinality_error_0_unscaled: 2.2500 (178.4932)  loss_ce_1_unscaled: 0.9020 (0.8126)  loss_bbox_1_unscaled: 0.0313 (0.0563)  loss_giou_1_unscaled: 0.4254 (0.5380)  cardinality_error_1_unscaled: 19.0000 (388.5338)  loss_ce_enc_unscaled: 0.8847 (0.7808)  loss_bbox_enc_unscaled: 0.0286 (0.0698)  loss_giou_enc_unscaled: 0.4465 (0.5632)  cardinality_error_enc_unscaled: 1.2500 (13.9595)
# Test:  [  0/171]  eta: 0:05:03  class_error: 0.00  loss: 6.9059 (6.9059)  loss_ce: 0.7682 (0.7682)  loss_bbox: 0.1723 (0.1723)  loss_giou: 0.7830 (0.7830)  loss_ce_0: 0.8309 (0.8309)  loss_bbox_0: 0.1581 (0.1581)  loss_giou_0: 0.7151 (0.7151)  loss_ce_1: 0.7717 (0.7717)  loss_bbox_1: 0.1737 (0.1737)  loss_giou_1: 0.7937 (0.7937)  loss_ce_enc: 0.7861 (0.7861)  loss_bbox_enc: 0.1694 (0.1694)  loss_giou_enc: 0.7838 (0.7838)  loss_ce_unscaled: 0.7682 (0.7682)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0345 (0.0345)  loss_giou_unscaled: 0.3915 (0.3915)  cardinality_error_unscaled: 268.5000 (268.5000)  loss_ce_0_unscaled: 0.8309 (0.8309)  loss_bbox_0_unscaled: 0.0316 (0.0316)  loss_giou_0_unscaled: 0.3576 (0.3576)  cardinality_error_0_unscaled: 138.7500 (138.7500)  loss_ce_1_unscaled: 0.7717 (0.7717)  loss_bbox_1_unscaled: 0.0347 (0.0347)  loss_giou_1_unscaled: 0.3968 (0.3968)  cardinality_error_1_unscaled: 234.5000 (234.5000)  loss_ce_enc_unscaled: 0.7861 (0.7861)  loss_bbox_enc_unscaled: 0.0339 (0.0339)  loss_giou_enc_unscaled: 0.3919 (0.3919)  cardinality_error_enc_unscaled: 2.2500 (2.2500)  time: 1.7756  data: 0.1805
# Test:  [ 10/171]  eta: 0:03:35  class_error: 18.75  loss: 7.7278 (7.6707)  loss_ce: 0.9534 (0.9187)  loss_bbox: 0.1410 (0.1294)  loss_giou: 0.8311 (0.8634)  loss_ce_0: 0.9481 (0.8994)  loss_bbox_0: 0.1328 (0.1301)  loss_giou_0: 0.8879 (0.8869)  loss_ce_1: 0.9815 (0.9407)  loss_bbox_1: 0.1186 (0.1244)  loss_giou_1: 0.8679 (0.8638)  loss_ce_enc: 0.9195 (0.8983)  loss_bbox_enc: 0.1476 (0.1330)  loss_giou_enc: 0.8415 (0.8826)  loss_ce_unscaled: 0.9534 (0.9187)  class_error_unscaled: 0.0000 (17.0292)  loss_bbox_unscaled: 0.0282 (0.0259)  loss_giou_unscaled: 0.4155 (0.4317)  cardinality_error_unscaled: 282.7500 (283.3409)  loss_ce_0_unscaled: 0.9481 (0.8994)  loss_bbox_0_unscaled: 0.0266 (0.0260)  loss_giou_0_unscaled: 0.4439 (0.4435)  cardinality_error_0_unscaled: 218.2500 (211.5909)  loss_ce_1_unscaled: 0.9815 (0.9407)  loss_bbox_1_unscaled: 0.0237 (0.0249)  loss_giou_1_unscaled: 0.4339 (0.4319)  cardinality_error_1_unscaled: 277.2500 (272.5455)  loss_ce_enc_unscaled: 0.9195 (0.8983)  loss_bbox_enc_unscaled: 0.0295 (0.0266)  loss_giou_enc_unscaled: 0.4207 (0.4413)  cardinality_error_enc_unscaled: 1.7500 (2.0682)  time: 1.3378  data: 0.0749
# Test:  [ 20/171]  eta: 0:03:17  class_error: 0.00  loss: 8.0194 (7.9247)  loss_ce: 0.9758 (0.9764)  loss_bbox: 0.1319 (0.1449)  loss_giou: 0.8311 (0.8680)  loss_ce_0: 0.9245 (0.9171)  loss_bbox_0: 0.1328 (0.1469)  loss_giou_0: 0.8767 (0.8897)  loss_ce_1: 0.9898 (0.9899)  loss_bbox_1: 0.1350 (0.1442)  loss_giou_1: 0.8679 (0.8788)  loss_ce_enc: 0.9045 (0.8942)  loss_bbox_enc: 0.1554 (0.1611)  loss_giou_enc: 0.8783 (0.9137)  loss_ce_unscaled: 0.9758 (0.9764)  class_error_unscaled: 21.4286 (27.4915)  loss_bbox_unscaled: 0.0264 (0.0290)  loss_giou_unscaled: 0.4155 (0.4340)  cardinality_error_unscaled: 285.5000 (285.3810)  loss_ce_0_unscaled: 0.9245 (0.9171)  loss_bbox_0_unscaled: 0.0266 (0.0294)  loss_giou_0_unscaled: 0.4383 (0.4449)  cardinality_error_0_unscaled: 201.2500 (203.7143)  loss_ce_1_unscaled: 0.9898 (0.9899)  loss_bbox_1_unscaled: 0.0270 (0.0288)  loss_giou_1_unscaled: 0.4339 (0.4394)  cardinality_error_1_unscaled: 278.2500 (276.6071)  loss_ce_enc_unscaled: 0.9045 (0.8942)  loss_bbox_enc_unscaled: 0.0311 (0.0322)  loss_giou_enc_unscaled: 0.4391 (0.4568)  cardinality_error_enc_unscaled: 1.7500 (1.9286)  time: 1.2868  data: 0.0650
# Test:  [ 30/171]  eta: 0:03:02  class_error: 37.50  loss: 8.0156 (7.6224)  loss_ce: 0.9106 (0.9290)  loss_bbox: 0.1420 (0.1469)  loss_giou: 0.8212 (0.8501)  loss_ce_0: 0.8799 (0.8759)  loss_bbox_0: 0.1421 (0.1457)  loss_giou_0: 0.8334 (0.8535)  loss_ce_1: 0.9187 (0.9421)  loss_bbox_1: 0.1466 (0.1457)  loss_giou_1: 0.8603 (0.8538)  loss_ce_enc: 0.7625 (0.8386)  loss_bbox_enc: 0.1568 (0.1595)  loss_giou_enc: 0.8810 (0.8815)  loss_ce_unscaled: 0.9106 (0.9290)  class_error_unscaled: 25.0000 (26.8222)  loss_bbox_unscaled: 0.0284 (0.0294)  loss_giou_unscaled: 0.4106 (0.4251)  cardinality_error_unscaled: 285.0000 (285.0081)  loss_ce_0_unscaled: 0.8799 (0.8759)  loss_bbox_0_unscaled: 0.0284 (0.0291)  loss_giou_0_unscaled: 0.4167 (0.4268)  cardinality_error_0_unscaled: 153.7500 (184.9274)  loss_ce_1_unscaled: 0.9187 (0.9421)  loss_bbox_1_unscaled: 0.0293 (0.0291)  loss_giou_1_unscaled: 0.4302 (0.4269)  cardinality_error_1_unscaled: 276.7500 (275.1210)  loss_ce_enc_unscaled: 0.7625 (0.8386)  loss_bbox_enc_unscaled: 0.0314 (0.0319)  loss_giou_enc_unscaled: 0.4405 (0.4407)  cardinality_error_enc_unscaled: 1.0000 (1.6452)  time: 1.2708  data: 0.0641
# Test:  [ 40/171]  eta: 0:02:50  class_error: 0.00  loss: 7.3853 (7.4651)  loss_ce: 0.8593 (0.9111)  loss_bbox: 0.1420 (0.1424)  loss_giou: 0.7741 (0.8327)  loss_ce_0: 0.8522 (0.8664)  loss_bbox_0: 0.1172 (0.1410)  loss_giou_0: 0.7611 (0.8328)  loss_ce_1: 0.8667 (0.9223)  loss_bbox_1: 0.1390 (0.1409)  loss_giou_1: 0.7678 (0.8345)  loss_ce_enc: 0.7559 (0.8262)  loss_bbox_enc: 0.1455 (0.1537)  loss_giou_enc: 0.8028 (0.8612)  loss_ce_unscaled: 0.8593 (0.9111)  class_error_unscaled: 0.0000 (25.8935)  loss_bbox_unscaled: 0.0284 (0.0285)  loss_giou_unscaled: 0.3870 (0.4164)  cardinality_error_unscaled: 285.0000 (285.9329)  loss_ce_0_unscaled: 0.8522 (0.8664)  loss_bbox_0_unscaled: 0.0234 (0.0282)  loss_giou_0_unscaled: 0.3805 (0.4164)  cardinality_error_0_unscaled: 153.7500 (185.6280)  loss_ce_1_unscaled: 0.8667 (0.9223)  loss_bbox_1_unscaled: 0.0278 (0.0282)  loss_giou_1_unscaled: 0.3839 (0.4173)  cardinality_error_1_unscaled: 272.5000 (275.5122)  loss_ce_enc_unscaled: 0.7559 (0.8262)  loss_bbox_enc_unscaled: 0.0291 (0.0307)  loss_giou_enc_unscaled: 0.4014 (0.4306)  cardinality_error_enc_unscaled: 1.0000 (1.5976)  time: 1.2928  data: 0.0642
# Test:  [ 50/171]  eta: 0:02:36  class_error: 10.00  loss: 7.3701 (7.3927)  loss_ce: 0.8593 (0.8989)  loss_bbox: 0.1044 (0.1379)  loss_giou: 0.7770 (0.8256)  loss_ce_0: 0.8287 (0.8594)  loss_bbox_0: 0.1080 (0.1380)  loss_giou_0: 0.7959 (0.8290)  loss_ce_1: 0.9270 (0.9140)  loss_bbox_1: 0.1018 (0.1377)  loss_giou_1: 0.7970 (0.8275)  loss_ce_enc: 0.7384 (0.8203)  loss_bbox_enc: 0.1216 (0.1494)  loss_giou_enc: 0.8641 (0.8552)  loss_ce_unscaled: 0.8593 (0.8989)  class_error_unscaled: 0.0000 (22.2107)  loss_bbox_unscaled: 0.0209 (0.0276)  loss_giou_unscaled: 0.3885 (0.4128)  cardinality_error_unscaled: 288.2500 (285.5686)  loss_ce_0_unscaled: 0.8287 (0.8594)  loss_bbox_0_unscaled: 0.0216 (0.0276)  loss_giou_0_unscaled: 0.3980 (0.4145)  cardinality_error_0_unscaled: 189.5000 (190.4265)  loss_ce_1_unscaled: 0.9270 (0.9140)  loss_bbox_1_unscaled: 0.0204 (0.0275)  loss_giou_1_unscaled: 0.3985 (0.4137)  cardinality_error_1_unscaled: 277.5000 (274.5588)  loss_ce_enc_unscaled: 0.7384 (0.8203)  loss_bbox_enc_unscaled: 0.0243 (0.0299)  loss_giou_enc_unscaled: 0.4321 (0.4276)  cardinality_error_enc_unscaled: 2.0000 (1.7304)  time: 1.2998  data: 0.0666
# Test:  [ 60/171]  eta: 0:02:23  class_error: 12.50  loss: 7.4863 (7.4010)  loss_ce: 0.8389 (0.8934)  loss_bbox: 0.1516 (0.1458)  loss_giou: 0.8331 (0.8249)  loss_ce_0: 0.8106 (0.8563)  loss_bbox_0: 0.1487 (0.1449)  loss_giou_0: 0.7959 (0.8210)  loss_ce_1: 0.8506 (0.9115)  loss_bbox_1: 0.1539 (0.1459)  loss_giou_1: 0.8285 (0.8280)  loss_ce_enc: 0.7389 (0.8097)  loss_bbox_enc: 0.1586 (0.1602)  loss_giou_enc: 0.9018 (0.8593)  loss_ce_unscaled: 0.8389 (0.8934)  class_error_unscaled: 0.0000 (19.6397)  loss_bbox_unscaled: 0.0303 (0.0292)  loss_giou_unscaled: 0.4166 (0.4125)  cardinality_error_unscaled: 274.7500 (283.5902)  loss_ce_0_unscaled: 0.8106 (0.8563)  loss_bbox_0_unscaled: 0.0297 (0.0290)  loss_giou_0_unscaled: 0.3980 (0.4105)  cardinality_error_0_unscaled: 157.5000 (185.2172)  loss_ce_1_unscaled: 0.8506 (0.9115)  loss_bbox_1_unscaled: 0.0308 (0.0292)  loss_giou_1_unscaled: 0.4143 (0.4140)  cardinality_error_1_unscaled: 250.0000 (270.4836)  loss_ce_enc_unscaled: 0.7389 (0.8097)  loss_bbox_enc_unscaled: 0.0317 (0.0320)  loss_giou_enc_unscaled: 0.4509 (0.4297)  cardinality_error_enc_unscaled: 2.2500 (1.8074)  time: 1.2685  data: 0.0667
# Test:  [ 70/171]  eta: 0:02:09  class_error: 0.00  loss: 7.5275 (7.4063)  loss_ce: 0.8024 (0.8761)  loss_bbox: 0.1981 (0.1578)  loss_giou: 0.8611 (0.8317)  loss_ce_0: 0.7986 (0.8470)  loss_bbox_0: 0.2115 (0.1555)  loss_giou_0: 0.8274 (0.8238)  loss_ce_1: 0.8087 (0.8926)  loss_bbox_1: 0.1997 (0.1572)  loss_giou_1: 0.8589 (0.8322)  loss_ce_enc: 0.7506 (0.8041)  loss_bbox_enc: 0.2341 (0.1695)  loss_giou_enc: 0.8828 (0.8587)  loss_ce_unscaled: 0.8024 (0.8761)  class_error_unscaled: 0.0000 (17.7420)  loss_bbox_unscaled: 0.0396 (0.0316)  loss_giou_unscaled: 0.4306 (0.4158)  cardinality_error_unscaled: 267.2500 (280.7465)  loss_ce_0_unscaled: 0.7986 (0.8470)  loss_bbox_0_unscaled: 0.0423 (0.0311)  loss_giou_0_unscaled: 0.4137 (0.4119)  cardinality_error_0_unscaled: 136.5000 (177.4014)  loss_ce_1_unscaled: 0.8087 (0.8926)  loss_bbox_1_unscaled: 0.0399 (0.0314)  loss_giou_1_unscaled: 0.4294 (0.4161)  cardinality_error_1_unscaled: 238.5000 (265.4965)  loss_ce_enc_unscaled: 0.7506 (0.8041)  loss_bbox_enc_unscaled: 0.0468 (0.0339)  loss_giou_enc_unscaled: 0.4414 (0.4293)  cardinality_error_enc_unscaled: 2.5000 (2.0211)  time: 1.2587  data: 0.0669
# Test:  [ 80/171]  eta: 0:01:57  class_error: 0.00  loss: 7.5275 (7.4012)  loss_ce: 0.8118 (0.8780)  loss_bbox: 0.1901 (0.1557)  loss_giou: 0.8510 (0.8330)  loss_ce_0: 0.7836 (0.8469)  loss_bbox_0: 0.1899 (0.1546)  loss_giou_0: 0.8290 (0.8236)  loss_ce_1: 0.7927 (0.8951)  loss_bbox_1: 0.1890 (0.1546)  loss_giou_1: 0.8307 (0.8299)  loss_ce_enc: 0.7482 (0.8052)  loss_bbox_enc: 0.1912 (0.1672)  loss_giou_enc: 0.8295 (0.8576)  loss_ce_unscaled: 0.8118 (0.8780)  class_error_unscaled: 0.0000 (19.5514)  loss_bbox_unscaled: 0.0380 (0.0311)  loss_giou_unscaled: 0.4255 (0.4165)  cardinality_error_unscaled: 267.2500 (280.9043)  loss_ce_0_unscaled: 0.7836 (0.8469)  loss_bbox_0_unscaled: 0.0380 (0.0309)  loss_giou_0_unscaled: 0.4145 (0.4118)  cardinality_error_0_unscaled: 136.5000 (179.5278)  loss_ce_1_unscaled: 0.7927 (0.8951)  loss_bbox_1_unscaled: 0.0378 (0.0309)  loss_giou_1_unscaled: 0.4153 (0.4150)  cardinality_error_1_unscaled: 241.0000 (265.6759)  loss_ce_enc_unscaled: 0.7482 (0.8052)  loss_bbox_enc_unscaled: 0.0382 (0.0334)  loss_giou_enc_unscaled: 0.4147 (0.4288)  cardinality_error_enc_unscaled: 2.2500 (1.9907)  time: 1.3014  data: 0.0682
# Test:  [ 90/171]  eta: 0:01:44  class_error: 0.00  loss: 7.5492 (7.1695)  loss_ce: 0.8430 (0.8762)  loss_bbox: 0.1399 (0.1487)  loss_giou: 0.7062 (0.7911)  loss_ce_0: 0.7883 (0.8297)  loss_bbox_0: 0.1376 (0.1487)  loss_giou_0: 0.6490 (0.7836)  loss_ce_1: 0.8832 (0.8938)  loss_bbox_1: 0.1366 (0.1489)  loss_giou_1: 0.6724 (0.7892)  loss_ce_enc: 0.7989 (0.7926)  loss_bbox_enc: 0.1255 (0.1577)  loss_giou_enc: 0.7063 (0.8094)  loss_ce_unscaled: 0.8430 (0.8762)  class_error_unscaled: 40.0000 (24.8755)  loss_bbox_unscaled: 0.0280 (0.0297)  loss_giou_unscaled: 0.3531 (0.3955)  cardinality_error_unscaled: 287.0000 (281.6978)  loss_ce_0_unscaled: 0.7883 (0.8297)  loss_bbox_0_unscaled: 0.0275 (0.0297)  loss_giou_0_unscaled: 0.3245 (0.3918)  cardinality_error_0_unscaled: 179.0000 (180.1676)  loss_ce_1_unscaled: 0.8832 (0.8938)  loss_bbox_1_unscaled: 0.0273 (0.0298)  loss_giou_1_unscaled: 0.3362 (0.3946)  cardinality_error_1_unscaled: 277.7500 (267.3929)  loss_ce_enc_unscaled: 0.7989 (0.7926)  loss_bbox_enc_unscaled: 0.0251 (0.0315)  loss_giou_enc_unscaled: 0.3531 (0.4047)  cardinality_error_enc_unscaled: 1.0000 (1.8654)  time: 1.3058  data: 0.0682
# Test:  [100/171]  eta: 0:01:31  class_error: 0.00  loss: 7.0828 (7.2071)  loss_ce: 0.9461 (0.8816)  loss_bbox: 0.1409 (0.1499)  loss_giou: 0.7177 (0.7953)  loss_ce_0: 0.9195 (0.8395)  loss_bbox_0: 0.1312 (0.1485)  loss_giou_0: 0.6874 (0.7836)  loss_ce_1: 0.9618 (0.8997)  loss_bbox_1: 0.1323 (0.1492)  loss_giou_1: 0.6909 (0.7921)  loss_ce_enc: 0.8684 (0.7993)  loss_bbox_enc: 0.1325 (0.1577)  loss_giou_enc: 0.7063 (0.8109)  loss_ce_unscaled: 0.9461 (0.8816)  class_error_unscaled: 25.0000 (23.8977)  loss_bbox_unscaled: 0.0282 (0.0300)  loss_giou_unscaled: 0.3589 (0.3976)  cardinality_error_unscaled: 283.0000 (281.6460)  loss_ce_0_unscaled: 0.9195 (0.8395)  loss_bbox_0_unscaled: 0.0262 (0.0297)  loss_giou_0_unscaled: 0.3437 (0.3918)  cardinality_error_0_unscaled: 151.0000 (177.4257)  loss_ce_1_unscaled: 0.9618 (0.8997)  loss_bbox_1_unscaled: 0.0265 (0.0298)  loss_giou_1_unscaled: 0.3455 (0.3960)  cardinality_error_1_unscaled: 270.7500 (267.3614)  loss_ce_enc_unscaled: 0.8684 (0.7993)  loss_bbox_enc_unscaled: 0.0265 (0.0315)  loss_giou_enc_unscaled: 0.3531 (0.4054)  cardinality_error_enc_unscaled: 1.0000 (1.8416)  time: 1.2426  data: 0.0674
# Test:  [110/171]  eta: 0:01:17  class_error: 100.00  loss: 7.0681 (7.1665)  loss_ce: 0.8401 (0.8801)  loss_bbox: 0.1626 (0.1491)  loss_giou: 0.7496 (0.7880)  loss_ce_0: 0.8680 (0.8343)  loss_bbox_0: 0.1482 (0.1486)  loss_giou_0: 0.7193 (0.7770)  loss_ce_1: 0.9124 (0.8990)  loss_bbox_1: 0.1389 (0.1491)  loss_giou_1: 0.7561 (0.7859)  loss_ce_enc: 0.7928 (0.7964)  loss_bbox_enc: 0.1485 (0.1566)  loss_giou_enc: 0.7219 (0.8024)  loss_ce_unscaled: 0.8401 (0.8801)  class_error_unscaled: 0.0000 (24.2426)  loss_bbox_unscaled: 0.0325 (0.0298)  loss_giou_unscaled: 0.3748 (0.3940)  cardinality_error_unscaled: 281.2500 (281.5676)  loss_ce_0_unscaled: 0.8680 (0.8343)  loss_bbox_0_unscaled: 0.0296 (0.0297)  loss_giou_0_unscaled: 0.3597 (0.3885)  cardinality_error_0_unscaled: 151.7500 (178.9279)  loss_ce_1_unscaled: 0.9124 (0.8990)  loss_bbox_1_unscaled: 0.0278 (0.0298)  loss_giou_1_unscaled: 0.3780 (0.3929)  cardinality_error_1_unscaled: 270.0000 (267.3559)  loss_ce_enc_unscaled: 0.7928 (0.7964)  loss_bbox_enc_unscaled: 0.0297 (0.0313)  loss_giou_enc_unscaled: 0.3610 (0.4012)  cardinality_error_enc_unscaled: 1.5000 (1.8536)  time: 1.2228  data: 0.0670
# Test:  [120/171]  eta: 0:01:04  class_error: 0.00  loss: 7.2840 (7.1468)  loss_ce: 1.0305 (0.8899)  loss_bbox: 0.0964 (0.1427)  loss_giou: 0.7210 (0.7761)  loss_ce_0: 0.8751 (0.8450)  loss_bbox_0: 0.1026 (0.1428)  loss_giou_0: 0.7291 (0.7700)  loss_ce_1: 1.0352 (0.9107)  loss_bbox_1: 0.0998 (0.1431)  loss_giou_1: 0.7554 (0.7767)  loss_ce_enc: 0.8723 (0.8080)  loss_bbox_enc: 0.1043 (0.1501)  loss_giou_enc: 0.7219 (0.7916)  loss_ce_unscaled: 1.0305 (0.8899)  class_error_unscaled: 0.0000 (23.0655)  loss_bbox_unscaled: 0.0193 (0.0285)  loss_giou_unscaled: 0.3605 (0.3881)  cardinality_error_unscaled: 297.5000 (282.9153)  loss_ce_0_unscaled: 0.8751 (0.8450)  loss_bbox_0_unscaled: 0.0205 (0.0286)  loss_giou_0_unscaled: 0.3646 (0.3850)  cardinality_error_0_unscaled: 242.7500 (184.1694)  loss_ce_1_unscaled: 1.0352 (0.9107)  loss_bbox_1_unscaled: 0.0200 (0.0286)  loss_giou_1_unscaled: 0.3777 (0.3883)  cardinality_error_1_unscaled: 293.2500 (269.5971)  loss_ce_enc_unscaled: 0.8723 (0.8080)  loss_bbox_enc_unscaled: 0.0209 (0.0300)  loss_giou_enc_unscaled: 0.3610 (0.3958)  cardinality_error_enc_unscaled: 1.2500 (1.7810)  time: 1.2192  data: 0.0656
# Test:  [130/171]  eta: 0:00:52  class_error: 0.00  loss: 7.4466 (7.1652)  loss_ce: 1.0677 (0.9028)  loss_bbox: 0.0772 (0.1389)  loss_giou: 0.6993 (0.7705)  loss_ce_0: 1.0404 (0.8624)  loss_bbox_0: 0.0804 (0.1390)  loss_giou_0: 0.6948 (0.7645)  loss_ce_1: 1.0899 (0.9221)  loss_bbox_1: 0.0789 (0.1393)  loss_giou_1: 0.7229 (0.7708)  loss_ce_enc: 1.0028 (0.8241)  loss_bbox_enc: 0.0844 (0.1459)  loss_giou_enc: 0.7080 (0.7849)  loss_ce_unscaled: 1.0677 (0.9028)  class_error_unscaled: 0.0000 (21.4320)  loss_bbox_unscaled: 0.0154 (0.0278)  loss_giou_unscaled: 0.3496 (0.3852)  cardinality_error_unscaled: 297.2500 (283.6202)  loss_ce_0_unscaled: 1.0404 (0.8624)  loss_bbox_0_unscaled: 0.0161 (0.0278)  loss_giou_0_unscaled: 0.3474 (0.3822)  cardinality_error_0_unscaled: 225.7500 (184.1489)  loss_ce_1_unscaled: 1.0899 (0.9221)  loss_bbox_1_unscaled: 0.0158 (0.0279)  loss_giou_1_unscaled: 0.3615 (0.3854)  cardinality_error_1_unscaled: 292.0000 (270.7347)  loss_ce_enc_unscaled: 1.0028 (0.8241)  loss_bbox_enc_unscaled: 0.0169 (0.0292)  loss_giou_enc_unscaled: 0.3540 (0.3925)  cardinality_error_enc_unscaled: 1.0000 (1.7481)  time: 1.2317  data: 0.0642
# Test:  [140/171]  eta: 0:00:39  class_error: 0.00  loss: 7.2188 (7.1586)  loss_ce: 1.0869 (0.9184)  loss_bbox: 0.0730 (0.1334)  loss_giou: 0.6478 (0.7549)  loss_ce_0: 1.0952 (0.8826)  loss_bbox_0: 0.0744 (0.1340)  loss_giou_0: 0.6406 (0.7521)  loss_ce_1: 1.1032 (0.9374)  loss_bbox_1: 0.0751 (0.1339)  loss_giou_1: 0.6369 (0.7566)  loss_ce_enc: 1.0539 (0.8462)  loss_bbox_enc: 0.0785 (0.1401)  loss_giou_enc: 0.6535 (0.7689)  loss_ce_unscaled: 1.0869 (0.9184)  class_error_unscaled: 0.0000 (19.9120)  loss_bbox_unscaled: 0.0146 (0.0267)  loss_giou_unscaled: 0.3239 (0.3775)  cardinality_error_unscaled: 296.0000 (284.5922)  loss_ce_0_unscaled: 1.0952 (0.8826)  loss_bbox_0_unscaled: 0.0149 (0.0268)  loss_giou_0_unscaled: 0.3203 (0.3760)  cardinality_error_0_unscaled: 198.0000 (188.5674)  loss_ce_1_unscaled: 1.1032 (0.9374)  loss_bbox_1_unscaled: 0.0150 (0.0268)  loss_giou_1_unscaled: 0.3185 (0.3783)  cardinality_error_1_unscaled: 292.0000 (272.4397)  loss_ce_enc_unscaled: 1.0539 (0.8462)  loss_bbox_enc_unscaled: 0.0157 (0.0280)  loss_giou_enc_unscaled: 0.3268 (0.3845)  cardinality_error_enc_unscaled: 1.0000 (1.6950)  time: 1.2341  data: 0.0635
# Test:  [150/171]  eta: 0:00:26  class_error: 100.00  loss: 6.7020 (7.1532)  loss_ce: 1.1200 (0.9283)  loss_bbox: 0.0537 (0.1286)  loss_giou: 0.4478 (0.7438)  loss_ce_0: 1.1905 (0.8987)  loss_bbox_0: 0.0639 (0.1295)  loss_giou_0: 0.4964 (0.7442)  loss_ce_1: 1.1439 (0.9484)  loss_bbox_1: 0.0538 (0.1291)  loss_giou_1: 0.4616 (0.7448)  loss_ce_enc: 1.1864 (0.8638)  loss_bbox_enc: 0.0587 (0.1353)  loss_giou_enc: 0.4594 (0.7588)  loss_ce_unscaled: 1.1200 (0.9283)  class_error_unscaled: 0.0000 (19.5867)  loss_bbox_unscaled: 0.0107 (0.0257)  loss_giou_unscaled: 0.2239 (0.3719)  cardinality_error_unscaled: 297.5000 (285.4205)  loss_ce_0_unscaled: 1.1905 (0.8987)  loss_bbox_0_unscaled: 0.0128 (0.0259)  loss_giou_0_unscaled: 0.2482 (0.3721)  cardinality_error_0_unscaled: 241.7500 (190.7831)  loss_ce_1_unscaled: 1.1439 (0.9484)  loss_bbox_1_unscaled: 0.0108 (0.0258)  loss_giou_1_unscaled: 0.2308 (0.3724)  cardinality_error_1_unscaled: 294.2500 (273.8096)  loss_ce_enc_unscaled: 1.1864 (0.8638)  loss_bbox_enc_unscaled: 0.0117 (0.0271)  loss_giou_enc_unscaled: 0.2297 (0.3794)  cardinality_error_enc_unscaled: 1.0000 (1.6788)  time: 1.2095  data: 0.0638
# Test:  [160/171]  eta: 0:00:13  class_error: 25.00  loss: 7.1952 (7.1895)  loss_ce: 1.0016 (0.9288)  loss_bbox: 0.0981 (0.1324)  loss_giou: 0.7754 (0.7492)  loss_ce_0: 0.9775 (0.9004)  loss_bbox_0: 0.0701 (0.1333)  loss_giou_0: 0.7197 (0.7479)  loss_ce_1: 1.0084 (0.9489)  loss_bbox_1: 0.0884 (0.1323)  loss_giou_1: 0.7220 (0.7489)  loss_ce_enc: 0.9409 (0.8637)  loss_bbox_enc: 0.0753 (0.1391)  loss_giou_enc: 0.7743 (0.7646)  loss_ce_unscaled: 1.0016 (0.9288)  class_error_unscaled: 0.0000 (19.8919)  loss_bbox_unscaled: 0.0196 (0.0265)  loss_giou_unscaled: 0.3877 (0.3746)  cardinality_error_unscaled: 293.7500 (285.1366)  loss_ce_0_unscaled: 0.9775 (0.9004)  loss_bbox_0_unscaled: 0.0140 (0.0267)  loss_giou_0_unscaled: 0.3598 (0.3740)  cardinality_error_0_unscaled: 194.7500 (189.7360)  loss_ce_1_unscaled: 1.0084 (0.9489)  loss_bbox_1_unscaled: 0.0177 (0.0265)  loss_giou_1_unscaled: 0.3610 (0.3744)  cardinality_error_1_unscaled: 288.7500 (273.5186)  loss_ce_enc_unscaled: 0.9409 (0.8637)  loss_bbox_enc_unscaled: 0.0151 (0.0278)  loss_giou_enc_unscaled: 0.3872 (0.3823)  cardinality_error_enc_unscaled: 1.0000 (1.6755)  time: 1.2092  data: 0.0653
# Test:  [170/171]  eta: 0:00:01  class_error: 0.00  loss: 6.5269 (7.0732)  loss_ce: 0.8900 (0.9142)  loss_bbox: 0.1434 (0.1314)  loss_giou: 0.7252 (0.7373)  loss_ce_0: 0.8887 (0.8845)  loss_bbox_0: 0.1413 (0.1322)  loss_giou_0: 0.6898 (0.7354)  loss_ce_1: 0.9037 (0.9333)  loss_bbox_1: 0.1382 (0.1312)  loss_giou_1: 0.6941 (0.7367)  loss_ce_enc: 0.7540 (0.8462)  loss_bbox_enc: 0.1571 (0.1379)  loss_giou_enc: 0.7618 (0.7531)  loss_ce_unscaled: 0.8900 (0.9142)  class_error_unscaled: 0.0000 (19.9470)  loss_bbox_unscaled: 0.0287 (0.0263)  loss_giou_unscaled: 0.3626 (0.3686)  cardinality_error_unscaled: 282.5000 (284.6974)  loss_ce_0_unscaled: 0.8887 (0.8845)  loss_bbox_0_unscaled: 0.0283 (0.0264)  loss_giou_0_unscaled: 0.3449 (0.3677)  cardinality_error_0_unscaled: 152.2500 (187.5877)  loss_ce_1_unscaled: 0.9037 (0.9333)  loss_bbox_1_unscaled: 0.0276 (0.0262)  loss_giou_1_unscaled: 0.3471 (0.3683)  cardinality_error_1_unscaled: 266.7500 (272.2383)  loss_ce_enc_unscaled: 0.7540 (0.8462)  loss_bbox_enc_unscaled: 0.0314 (0.0276)  loss_giou_enc_unscaled: 0.3809 (0.3765)  cardinality_error_enc_unscaled: 1.0000 (1.6608)  time: 1.1524  data: 0.0605
# Test: Total time: 0:03:33 (1.2502 s / it)
# Averaged stats: class_error: 0.00  loss: 6.5269 (7.0732)  loss_ce: 0.8900 (0.9142)  loss_bbox: 0.1434 (0.1314)  loss_giou: 0.7252 (0.7373)  loss_ce_0: 0.8887 (0.8845)  loss_bbox_0: 0.1413 (0.1322)  loss_giou_0: 0.6898 (0.7354)  loss_ce_1: 0.9037 (0.9333)  loss_bbox_1: 0.1382 (0.1312)  loss_giou_1: 0.6941 (0.7367)  loss_ce_enc: 0.7540 (0.8462)  loss_bbox_enc: 0.1571 (0.1379)  loss_giou_enc: 0.7618 (0.7531)  loss_ce_unscaled: 0.8900 (0.9142)  class_error_unscaled: 0.0000 (19.9470)  loss_bbox_unscaled: 0.0287 (0.0263)  loss_giou_unscaled: 0.3626 (0.3686)  cardinality_error_unscaled: 282.5000 (284.6974)  loss_ce_0_unscaled: 0.8887 (0.8845)  loss_bbox_0_unscaled: 0.0283 (0.0264)  loss_giou_0_unscaled: 0.3449 (0.3677)  cardinality_error_0_unscaled: 152.2500 (187.5877)  loss_ce_1_unscaled: 0.9037 (0.9333)  loss_bbox_1_unscaled: 0.0276 (0.0262)  loss_giou_1_unscaled: 0.3471 (0.3683)  cardinality_error_1_unscaled: 266.7500 (272.2383)  loss_ce_enc_unscaled: 0.7540 (0.8462)  loss_bbox_enc_unscaled: 0.0314 (0.0276)  loss_giou_enc_unscaled: 0.3809 (0.3765)  cardinality_error_enc_unscaled: 1.0000 (1.6608)
# Accumulating evaluation results...
# DONE (t=0.70s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.141
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.341
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.180
# Test:  [  0/171]  eta: 0:04:07  class_error: 0.00  loss: 6.9080 (6.9080)  loss_ce: 0.7693 (0.7693)  loss_bbox: 0.1728 (0.1728)  loss_giou: 0.7816 (0.7816)  loss_ce_0: 0.8350 (0.8350)  loss_bbox_0: 0.1585 (0.1585)  loss_giou_0: 0.7126 (0.7126)  loss_ce_1: 0.7723 (0.7723)  loss_bbox_1: 0.1744 (0.1744)  loss_giou_1: 0.7927 (0.7927)  loss_ce_enc: 0.7872 (0.7872)  loss_bbox_enc: 0.1707 (0.1707)  loss_giou_enc: 0.7809 (0.7809)  loss_ce_unscaled: 0.7693 (0.7693)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0346 (0.0346)  loss_giou_unscaled: 0.3908 (0.3908)  cardinality_error_unscaled: 265.7500 (265.7500)  loss_ce_0_unscaled: 0.8350 (0.8350)  loss_bbox_0_unscaled: 0.0317 (0.0317)  loss_giou_0_unscaled: 0.3563 (0.3563)  cardinality_error_0_unscaled: 123.5000 (123.5000)  loss_ce_1_unscaled: 0.7723 (0.7723)  loss_bbox_1_unscaled: 0.0349 (0.0349)  loss_giou_1_unscaled: 0.3964 (0.3964)  cardinality_error_1_unscaled: 230.2500 (230.2500)  loss_ce_enc_unscaled: 0.7872 (0.7872)  loss_bbox_enc_unscaled: 0.0341 (0.0341)  loss_giou_enc_unscaled: 0.3904 (0.3904)  cardinality_error_enc_unscaled: 2.2500 (2.2500)  time: 1.4464  data: 0.0548
# Test:  [ 10/171]  eta: 0:03:39  class_error: 18.75  loss: 7.6933 (7.6457)  loss_ce: 0.9504 (0.9072)  loss_bbox: 0.1346 (0.1296)  loss_giou: 0.8593 (0.8693)  loss_ce_0: 0.9381 (0.8965)  loss_bbox_0: 0.1325 (0.1315)  loss_giou_0: 0.8670 (0.8892)  loss_ce_1: 0.9554 (0.9240)  loss_bbox_1: 0.1214 (0.1247)  loss_giou_1: 0.8839 (0.8699)  loss_ce_enc: 0.9284 (0.8897)  loss_bbox_enc: 0.1455 (0.1303)  loss_giou_enc: 0.8462 (0.8838)  loss_ce_unscaled: 0.9504 (0.9072)  class_error_unscaled: 0.0000 (17.0292)  loss_bbox_unscaled: 0.0269 (0.0259)  loss_giou_unscaled: 0.4296 (0.4347)  cardinality_error_unscaled: 282.5000 (282.6591)  loss_ce_0_unscaled: 0.9381 (0.8965)  loss_bbox_0_unscaled: 0.0265 (0.0263)  loss_giou_0_unscaled: 0.4335 (0.4446)  cardinality_error_0_unscaled: 213.7500 (205.3182)  loss_ce_1_unscaled: 0.9554 (0.9240)  loss_bbox_1_unscaled: 0.0243 (0.0249)  loss_giou_1_unscaled: 0.4420 (0.4349)  cardinality_error_1_unscaled: 276.2500 (270.8864)  loss_ce_enc_unscaled: 0.9284 (0.8897)  loss_bbox_enc_unscaled: 0.0291 (0.0261)  loss_giou_enc_unscaled: 0.4231 (0.4419)  cardinality_error_enc_unscaled: 1.7500 (2.0682)  time: 1.3647  data: 0.0610
# Test:  [ 20/171]  eta: 0:03:25  class_error: 0.00  loss: 7.9893 (7.9007)  loss_ce: 0.9668 (0.9613)  loss_bbox: 0.1342 (0.1449)  loss_giou: 0.8593 (0.8744)  loss_ce_0: 0.9314 (0.9128)  loss_bbox_0: 0.1325 (0.1494)  loss_giou_0: 0.8670 (0.8970)  loss_ce_1: 0.9682 (0.9715)  loss_bbox_1: 0.1328 (0.1416)  loss_giou_1: 0.8839 (0.8780)  loss_ce_enc: 0.8871 (0.8842)  loss_bbox_enc: 0.1522 (0.1622)  loss_giou_enc: 0.8876 (0.9234)  loss_ce_unscaled: 0.9668 (0.9613)  class_error_unscaled: 20.0000 (27.1740)  loss_bbox_unscaled: 0.0268 (0.0290)  loss_giou_unscaled: 0.4296 (0.4372)  cardinality_error_unscaled: 285.7500 (284.6429)  loss_ce_0_unscaled: 0.9314 (0.9128)  loss_bbox_0_unscaled: 0.0265 (0.0299)  loss_giou_0_unscaled: 0.4335 (0.4485)  cardinality_error_0_unscaled: 193.7500 (197.4286)  loss_ce_1_unscaled: 0.9682 (0.9715)  loss_bbox_1_unscaled: 0.0266 (0.0283)  loss_giou_1_unscaled: 0.4420 (0.4390)  cardinality_error_1_unscaled: 276.5000 (275.0714)  loss_ce_enc_unscaled: 0.8871 (0.8842)  loss_bbox_enc_unscaled: 0.0304 (0.0324)  loss_giou_enc_unscaled: 0.4438 (0.4617)  cardinality_error_enc_unscaled: 1.7500 (1.9286)  time: 1.3586  data: 0.0623
# Test:  [ 30/171]  eta: 0:03:10  class_error: 37.50  loss: 7.9888 (7.5946)  loss_ce: 0.8989 (0.9147)  loss_bbox: 0.1455 (0.1470)  loss_giou: 0.8244 (0.8551)  loss_ce_0: 0.8881 (0.8753)  loss_bbox_0: 0.1429 (0.1469)  loss_giou_0: 0.8518 (0.8574)  loss_ce_1: 0.9317 (0.9266)  loss_bbox_1: 0.1425 (0.1429)  loss_giou_1: 0.8335 (0.8496)  loss_ce_enc: 0.7631 (0.8315)  loss_bbox_enc: 0.1612 (0.1603)  loss_giou_enc: 0.8865 (0.8873)  loss_ce_unscaled: 0.8989 (0.9147)  class_error_unscaled: 20.0000 (26.6071)  loss_bbox_unscaled: 0.0291 (0.0294)  loss_giou_unscaled: 0.4122 (0.4275)  cardinality_error_unscaled: 284.2500 (284.2097)  loss_ce_0_unscaled: 0.8881 (0.8753)  loss_bbox_0_unscaled: 0.0286 (0.0294)  loss_giou_0_unscaled: 0.4259 (0.4287)  cardinality_error_0_unscaled: 140.2500 (177.0484)  loss_ce_1_unscaled: 0.9317 (0.9266)  loss_bbox_1_unscaled: 0.0285 (0.0286)  loss_giou_1_unscaled: 0.4167 (0.4248)  cardinality_error_1_unscaled: 275.0000 (273.2742)  loss_ce_enc_unscaled: 0.7631 (0.8315)  loss_bbox_enc_unscaled: 0.0322 (0.0321)  loss_giou_enc_unscaled: 0.4432 (0.4436)  cardinality_error_enc_unscaled: 1.0000 (1.6452)  time: 1.3490  data: 0.0630
# Test:  [ 40/171]  eta: 0:02:56  class_error: 0.00  loss: 7.3571 (7.4366)  loss_ce: 0.8432 (0.8980)  loss_bbox: 0.1455 (0.1416)  loss_giou: 0.7768 (0.8358)  loss_ce_0: 0.8536 (0.8632)  loss_bbox_0: 0.1413 (0.1432)  loss_giou_0: 0.7516 (0.8386)  loss_ce_1: 0.8671 (0.9068)  loss_bbox_1: 0.1383 (0.1391)  loss_giou_1: 0.7616 (0.8320)  loss_ce_enc: 0.7527 (0.8209)  loss_bbox_enc: 0.1462 (0.1532)  loss_giou_enc: 0.7950 (0.8642)  loss_ce_unscaled: 0.8432 (0.8980)  class_error_unscaled: 12.5000 (26.0358)  loss_bbox_unscaled: 0.0291 (0.0283)  loss_giou_unscaled: 0.3884 (0.4179)  cardinality_error_unscaled: 284.2500 (285.1768)  loss_ce_0_unscaled: 0.8536 (0.8632)  loss_bbox_0_unscaled: 0.0283 (0.0286)  loss_giou_0_unscaled: 0.3758 (0.4193)  cardinality_error_0_unscaled: 140.2500 (177.5915)  loss_ce_1_unscaled: 0.8671 (0.9068)  loss_bbox_1_unscaled: 0.0277 (0.0278)  loss_giou_1_unscaled: 0.3808 (0.4160)  cardinality_error_1_unscaled: 271.0000 (273.5732)  loss_ce_enc_unscaled: 0.7527 (0.8209)  loss_bbox_enc_unscaled: 0.0292 (0.0306)  loss_giou_enc_unscaled: 0.3975 (0.4321)  cardinality_error_enc_unscaled: 1.0000 (1.5976)  time: 1.3382  data: 0.0624
# Test:  [ 50/171]  eta: 0:02:41  class_error: 10.00  loss: 7.3571 (7.3651)  loss_ce: 0.8432 (0.8885)  loss_bbox: 0.0993 (0.1367)  loss_giou: 0.7525 (0.8274)  loss_ce_0: 0.8293 (0.8588)  loss_bbox_0: 0.1076 (0.1392)  loss_giou_0: 0.7979 (0.8320)  loss_ce_1: 0.8855 (0.9000)  loss_bbox_1: 0.1136 (0.1357)  loss_giou_1: 0.7616 (0.8246)  loss_ce_enc: 0.7369 (0.8156)  loss_bbox_enc: 0.1174 (0.1485)  loss_giou_enc: 0.8696 (0.8579)  loss_ce_unscaled: 0.8432 (0.8885)  class_error_unscaled: 0.0000 (22.4122)  loss_bbox_unscaled: 0.0199 (0.0273)  loss_giou_unscaled: 0.3762 (0.4137)  cardinality_error_unscaled: 287.5000 (284.8333)  loss_ce_0_unscaled: 0.8293 (0.8588)  loss_bbox_0_unscaled: 0.0215 (0.0278)  loss_giou_0_unscaled: 0.3989 (0.4160)  cardinality_error_0_unscaled: 185.7500 (183.2990)  loss_ce_1_unscaled: 0.8855 (0.9000)  loss_bbox_1_unscaled: 0.0227 (0.0271)  loss_giou_1_unscaled: 0.3808 (0.4123)  cardinality_error_1_unscaled: 276.0000 (272.6814)  loss_ce_enc_unscaled: 0.7369 (0.8156)  loss_bbox_enc_unscaled: 0.0235 (0.0297)  loss_giou_enc_unscaled: 0.4348 (0.4290)  cardinality_error_enc_unscaled: 2.0000 (1.7304)  time: 1.3135  data: 0.0599
# Test:  [ 60/171]  eta: 0:02:27  class_error: 12.50  loss: 7.4209 (7.3708)  loss_ce: 0.8413 (0.8835)  loss_bbox: 0.1319 (0.1442)  loss_giou: 0.8009 (0.8250)  loss_ce_0: 0.8085 (0.8547)  loss_bbox_0: 0.1428 (0.1462)  loss_giou_0: 0.7979 (0.8245)  loss_ce_1: 0.8588 (0.8965)  loss_bbox_1: 0.1521 (0.1442)  loss_giou_1: 0.8184 (0.8247)  loss_ce_enc: 0.7444 (0.8054)  loss_bbox_enc: 0.1602 (0.1584)  loss_giou_enc: 0.8871 (0.8636)  loss_ce_unscaled: 0.8413 (0.8835)  class_error_unscaled: 0.0000 (19.8082)  loss_bbox_unscaled: 0.0264 (0.0288)  loss_giou_unscaled: 0.4004 (0.4125)  cardinality_error_unscaled: 272.7500 (282.7664)  loss_ce_0_unscaled: 0.8085 (0.8547)  loss_bbox_0_unscaled: 0.0286 (0.0292)  loss_giou_0_unscaled: 0.3989 (0.4122)  cardinality_error_0_unscaled: 153.2500 (178.1639)  loss_ce_1_unscaled: 0.8588 (0.8965)  loss_bbox_1_unscaled: 0.0304 (0.0288)  loss_giou_1_unscaled: 0.4092 (0.4123)  cardinality_error_1_unscaled: 248.0000 (268.5205)  loss_ce_enc_unscaled: 0.7444 (0.8054)  loss_bbox_enc_unscaled: 0.0320 (0.0317)  loss_giou_enc_unscaled: 0.4435 (0.4318)  cardinality_error_enc_unscaled: 2.2500 (1.8074)  time: 1.2797  data: 0.0590
# Test:  [ 70/171]  eta: 0:02:13  class_error: 0.00  loss: 7.5145 (7.3825)  loss_ce: 0.8026 (0.8684)  loss_bbox: 0.1988 (0.1563)  loss_giou: 0.8501 (0.8308)  loss_ce_0: 0.8024 (0.8457)  loss_bbox_0: 0.2069 (0.1569)  loss_giou_0: 0.8262 (0.8279)  loss_ce_1: 0.8007 (0.8804)  loss_bbox_1: 0.2055 (0.1556)  loss_giou_1: 0.8470 (0.8287)  loss_ce_enc: 0.7502 (0.8006)  loss_bbox_enc: 0.2278 (0.1682)  loss_giou_enc: 0.8583 (0.8628)  loss_ce_unscaled: 0.8026 (0.8684)  class_error_unscaled: 0.0000 (17.8867)  loss_bbox_unscaled: 0.0398 (0.0313)  loss_giou_unscaled: 0.4251 (0.4154)  cardinality_error_unscaled: 266.0000 (279.8063)  loss_ce_0_unscaled: 0.8024 (0.8457)  loss_bbox_0_unscaled: 0.0414 (0.0314)  loss_giou_0_unscaled: 0.4131 (0.4139)  cardinality_error_0_unscaled: 128.7500 (170.4789)  loss_ce_1_unscaled: 0.8007 (0.8804)  loss_bbox_1_unscaled: 0.0411 (0.0311)  loss_giou_1_unscaled: 0.4235 (0.4144)  cardinality_error_1_unscaled: 235.0000 (263.2852)  loss_ce_enc_unscaled: 0.7502 (0.8006)  loss_bbox_enc_unscaled: 0.0456 (0.0336)  loss_giou_enc_unscaled: 0.4292 (0.4314)  cardinality_error_enc_unscaled: 2.5000 (2.0211)  time: 1.2911  data: 0.0622
# Test:  [ 80/171]  eta: 0:02:00  class_error: 0.00  loss: 7.5346 (7.3773)  loss_ce: 0.8119 (0.8711)  loss_bbox: 0.1910 (0.1541)  loss_giou: 0.8530 (0.8313)  loss_ce_0: 0.7851 (0.8461)  loss_bbox_0: 0.1886 (0.1558)  loss_giou_0: 0.8356 (0.8269)  loss_ce_1: 0.7928 (0.8840)  loss_bbox_1: 0.1888 (0.1531)  loss_giou_1: 0.8363 (0.8255)  loss_ce_enc: 0.7620 (0.8033)  loss_bbox_enc: 0.1897 (0.1657)  loss_giou_enc: 0.8380 (0.8604)  loss_ce_unscaled: 0.8119 (0.8711)  class_error_unscaled: 0.0000 (19.6783)  loss_bbox_unscaled: 0.0382 (0.0308)  loss_giou_unscaled: 0.4265 (0.4157)  cardinality_error_unscaled: 266.0000 (279.9815)  loss_ce_0_unscaled: 0.7851 (0.8461)  loss_bbox_0_unscaled: 0.0377 (0.0312)  loss_giou_0_unscaled: 0.4178 (0.4134)  cardinality_error_0_unscaled: 128.7500 (172.6204)  loss_ce_1_unscaled: 0.7928 (0.8840)  loss_bbox_1_unscaled: 0.0378 (0.0306)  loss_giou_1_unscaled: 0.4181 (0.4127)  cardinality_error_1_unscaled: 238.2500 (263.5556)  loss_ce_enc_unscaled: 0.7620 (0.8033)  loss_bbox_enc_unscaled: 0.0379 (0.0331)  loss_giou_enc_unscaled: 0.4190 (0.4302)  cardinality_error_enc_unscaled: 2.2500 (1.9907)  time: 1.3101  data: 0.0618
# Test:  [ 90/171]  eta: 0:01:46  class_error: 0.00  loss: 7.5346 (7.1426)  loss_ce: 0.8520 (0.8652)  loss_bbox: 0.1213 (0.1482)  loss_giou: 0.6798 (0.7915)  loss_ce_0: 0.7974 (0.8270)  loss_bbox_0: 0.1420 (0.1502)  loss_giou_0: 0.6587 (0.7880)  loss_ce_1: 0.8650 (0.8770)  loss_bbox_1: 0.1353 (0.1481)  loss_giou_1: 0.7158 (0.7877)  loss_ce_enc: 0.8003 (0.7892)  loss_bbox_enc: 0.1248 (0.1570)  loss_giou_enc: 0.6983 (0.8136)  loss_ce_unscaled: 0.8520 (0.8652)  class_error_unscaled: 40.0000 (24.9884)  loss_bbox_unscaled: 0.0243 (0.0296)  loss_giou_unscaled: 0.3399 (0.3957)  cardinality_error_unscaled: 286.5000 (280.7555)  loss_ce_0_unscaled: 0.7974 (0.8270)  loss_bbox_0_unscaled: 0.0284 (0.0300)  loss_giou_0_unscaled: 0.3293 (0.3940)  cardinality_error_0_unscaled: 170.5000 (173.1621)  loss_ce_1_unscaled: 0.8650 (0.8770)  loss_bbox_1_unscaled: 0.0271 (0.0296)  loss_giou_1_unscaled: 0.3579 (0.3938)  cardinality_error_1_unscaled: 275.5000 (265.3681)  loss_ce_enc_unscaled: 0.8003 (0.7892)  loss_bbox_enc_unscaled: 0.0250 (0.0314)  loss_giou_enc_unscaled: 0.3492 (0.4068)  cardinality_error_enc_unscaled: 1.0000 (1.8654)  time: 1.2840  data: 0.0624
# Test:  [100/171]  eta: 0:01:33  class_error: 0.00  loss: 7.0700 (7.1788)  loss_ce: 0.9198 (0.8721)  loss_bbox: 0.1395 (0.1489)  loss_giou: 0.6798 (0.7938)  loss_ce_0: 0.9189 (0.8370)  loss_bbox_0: 0.1307 (0.1499)  loss_giou_0: 0.6615 (0.7875)  loss_ce_1: 0.9579 (0.8842)  loss_bbox_1: 0.1227 (0.1482)  loss_giou_1: 0.6843 (0.7896)  loss_ce_enc: 0.8577 (0.7962)  loss_bbox_enc: 0.1329 (0.1569)  loss_giou_enc: 0.6983 (0.8145)  loss_ce_unscaled: 0.9198 (0.8721)  class_error_unscaled: 25.0000 (23.5044)  loss_bbox_unscaled: 0.0279 (0.0298)  loss_giou_unscaled: 0.3399 (0.3969)  cardinality_error_unscaled: 281.2500 (280.6708)  loss_ce_0_unscaled: 0.9189 (0.8370)  loss_bbox_0_unscaled: 0.0261 (0.0300)  loss_giou_0_unscaled: 0.3308 (0.3938)  cardinality_error_0_unscaled: 141.0000 (170.1460)  loss_ce_1_unscaled: 0.9579 (0.8842)  loss_bbox_1_unscaled: 0.0245 (0.0296)  loss_giou_1_unscaled: 0.3421 (0.3948)  cardinality_error_1_unscaled: 268.7500 (265.3292)  loss_ce_enc_unscaled: 0.8577 (0.7962)  loss_bbox_enc_unscaled: 0.0266 (0.0314)  loss_giou_enc_unscaled: 0.3492 (0.4072)  cardinality_error_enc_unscaled: 1.0000 (1.8416)  time: 1.2642  data: 0.0637
# Test:  [110/171]  eta: 0:01:19  class_error: 100.00  loss: 7.0504 (7.1393)  loss_ce: 0.8509 (0.8699)  loss_bbox: 0.1559 (0.1485)  loss_giou: 0.7699 (0.7876)  loss_ce_0: 0.8697 (0.8324)  loss_bbox_0: 0.1477 (0.1498)  loss_giou_0: 0.7257 (0.7803)  loss_ce_1: 0.9347 (0.8826)  loss_bbox_1: 0.1374 (0.1484)  loss_giou_1: 0.7344 (0.7840)  loss_ce_enc: 0.7952 (0.7935)  loss_bbox_enc: 0.1527 (0.1561)  loss_giou_enc: 0.7376 (0.8063)  loss_ce_unscaled: 0.8509 (0.8699)  class_error_unscaled: 0.0000 (23.8847)  loss_bbox_unscaled: 0.0312 (0.0297)  loss_giou_unscaled: 0.3850 (0.3938)  cardinality_error_unscaled: 279.2500 (280.6374)  loss_ce_0_unscaled: 0.8697 (0.8324)  loss_bbox_0_unscaled: 0.0295 (0.0300)  loss_giou_0_unscaled: 0.3629 (0.3901)  cardinality_error_0_unscaled: 143.2500 (171.8131)  loss_ce_1_unscaled: 0.9347 (0.8826)  loss_bbox_1_unscaled: 0.0275 (0.0297)  loss_giou_1_unscaled: 0.3672 (0.3920)  cardinality_error_1_unscaled: 267.7500 (265.3874)  loss_ce_enc_unscaled: 0.7952 (0.7935)  loss_bbox_enc_unscaled: 0.0305 (0.0312)  loss_giou_enc_unscaled: 0.3688 (0.4031)  cardinality_error_enc_unscaled: 1.5000 (1.8536)  time: 1.2861  data: 0.0625
# ...
# Training time 3 days, 3:02:29
# Results saved to D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\aicast_output\results.json
# Test:  [ 0/87]  eta: 0:02:35  class_error: 0.00  loss: 5.1739 (5.1739)  loss_ce: 0.6308 (0.6308)  loss_bbox: 0.0635 (0.0635)  loss_giou: 0.6081 (0.6081)  loss_ce_0: 0.7113 (0.7113)  loss_bbox_0: 0.0463 (0.0463)  loss_giou_0: 0.5007 (0.5007)  loss_ce_1: 0.6311 (0.6311)  loss_bbox_1: 0.0665 (0.0665)  loss_giou_1: 0.6159 (0.6159)  loss_ce_enc: 0.6091 (0.6091)  loss_bbox_enc: 0.0665 (0.0665)  loss_giou_enc: 0.6242 (0.6242)  loss_ce_unscaled: 0.6308 (0.6308)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0127 (0.0127)  loss_giou_unscaled: 0.3040 (0.3040)  cardinality_error_unscaled: 249.7500 (249.7500)  loss_ce_0_unscaled: 0.7113 (0.7113)  loss_bbox_0_unscaled: 0.0093 (0.0093)  loss_giou_0_unscaled: 0.2503 (0.2503)  cardinality_error_0_unscaled: 236.7500 (236.7500)  loss_ce_1_unscaled: 0.6311 (0.6311)  loss_bbox_1_unscaled: 0.0133 (0.0133)  loss_giou_1_unscaled: 0.3079 (0.3079)  cardinality_error_1_unscaled: 252.0000 (252.0000)  loss_ce_enc_unscaled: 0.6091 (0.6091)  loss_bbox_enc_unscaled: 0.0133 (0.0133)  loss_giou_enc_unscaled: 0.3121 (0.3121)  cardinality_error_enc_unscaled: 89.0000 (89.0000)  time: 1.7886  data: 0.1086
# Test:  [10/87]  eta: 0:02:08  class_error: 0.00  loss: 5.3235 (5.1542)  loss_ce: 0.6244 (0.6050)  loss_bbox: 0.0825 (0.0843)  loss_giou: 0.6123 (0.5815)  loss_ce_0: 0.6348 (0.6131)  loss_bbox_0: 0.0837 (0.0843)  loss_giou_0: 0.6073 (0.5827)  loss_ce_1: 0.6311 (0.5992)  loss_bbox_1: 0.0803 (0.0847)  loss_giou_1: 0.6159 (0.5804)  loss_ce_enc: 0.6503 (0.6396)  loss_bbox_enc: 0.0833 (0.0903)  loss_giou_enc: 0.6211 (0.6091)  loss_ce_unscaled: 0.6244 (0.6050)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0165 (0.0169)  loss_giou_unscaled: 0.3062 (0.2908)  cardinality_error_unscaled: 253.5000 (253.0227)  loss_ce_0_unscaled: 0.6348 (0.6131)  loss_bbox_0_unscaled: 0.0167 (0.0169)  loss_giou_0_unscaled: 0.3036 (0.2913)  cardinality_error_0_unscaled: 254.5000 (247.5000)  loss_ce_1_unscaled: 0.6311 (0.5992)  loss_bbox_1_unscaled: 0.0161 (0.0169)  loss_giou_1_unscaled: 0.3079 (0.2902)  cardinality_error_1_unscaled: 262.5000 (247.4545)  loss_ce_enc_unscaled: 0.6503 (0.6396)  loss_bbox_enc_unscaled: 0.0167 (0.0181)  loss_giou_enc_unscaled: 0.3106 (0.3046)  cardinality_error_enc_unscaled: 207.5000 (181.7273)  time: 1.6696  data: 0.0903
# Test:  [20/87]  eta: 0:01:56  class_error: 0.00  loss: 5.1619 (5.2820)  loss_ce: 0.6007 (0.5938)  loss_bbox: 0.0775 (0.0862)  loss_giou: 0.6123 (0.6313)  loss_ce_0: 0.6065 (0.6043)  loss_bbox_0: 0.0752 (0.0863)  loss_giou_0: 0.6211 (0.6352)  loss_ce_1: 0.5960 (0.5901)  loss_bbox_1: 0.0774 (0.0864)  loss_giou_1: 0.5992 (0.6303)  loss_ce_enc: 0.6219 (0.6341)  loss_bbox_enc: 0.0762 (0.0857)  loss_giou_enc: 0.6167 (0.6182)  loss_ce_unscaled: 0.6007 (0.5938)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0155 (0.0172)  loss_giou_unscaled: 0.3062 (0.3157)  cardinality_error_unscaled: 253.5000 (249.8929)  loss_ce_0_unscaled: 0.6065 (0.6043)  loss_bbox_0_unscaled: 0.0150 (0.0173)  loss_giou_0_unscaled: 0.3105 (0.3176)  cardinality_error_0_unscaled: 223.0000 (232.6905)  loss_ce_1_unscaled: 0.5960 (0.5901)  loss_bbox_1_unscaled: 0.0155 (0.0173)  loss_giou_1_unscaled: 0.2996 (0.3152)  cardinality_error_1_unscaled: 243.0000 (237.2143)  loss_ce_enc_unscaled: 0.6219 (0.6341)  loss_bbox_enc_unscaled: 0.0152 (0.0171)  loss_giou_enc_unscaled: 0.3084 (0.3091)  cardinality_error_enc_unscaled: 140.7500 (149.1786)  time: 1.7415  data: 0.0942
# Test:  [30/87]  eta: 0:01:39  class_error: 0.00  loss: 5.2478 (5.2526)  loss_ce: 0.6024 (0.6031)  loss_bbox: 0.0775 (0.0870)  loss_giou: 0.6012 (0.6171)  loss_ce_0: 0.6032 (0.6104)  loss_bbox_0: 0.0752 (0.0869)  loss_giou_0: 0.6014 (0.6188)  loss_ce_1: 0.6010 (0.6003)  loss_bbox_1: 0.0774 (0.0869)  loss_giou_1: 0.6012 (0.6152)  loss_ce_enc: 0.6058 (0.6301)  loss_bbox_enc: 0.0771 (0.0867)  loss_giou_enc: 0.6145 (0.6100)  loss_ce_unscaled: 0.6024 (0.6031)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0155 (0.0174)  loss_giou_unscaled: 0.3006 (0.3086)  cardinality_error_unscaled: 241.5000 (248.1613)  loss_ce_0_unscaled: 0.6032 (0.6104)  loss_bbox_0_unscaled: 0.0150 (0.0174)  loss_giou_0_unscaled: 0.3007 (0.3094)  cardinality_error_0_unscaled: 214.0000 (224.7903)  loss_ce_1_unscaled: 0.6010 (0.6003)  loss_bbox_1_unscaled: 0.0155 (0.0174)  loss_giou_1_unscaled: 0.3006 (0.3076)  cardinality_error_1_unscaled: 239.7500 (239.6371)  loss_ce_enc_unscaled: 0.6058 (0.6301)  loss_bbox_enc_unscaled: 0.0154 (0.0173)  loss_giou_enc_unscaled: 0.3073 (0.3050)  cardinality_error_enc_unscaled: 114.2500 (143.0081)  time: 1.7952  data: 0.0991
# Test:  [40/87]  eta: 0:01:20  class_error: 0.00  loss: 5.3079 (5.2937)  loss_ce: 0.6048 (0.6060)  loss_bbox: 0.1122 (0.0915)  loss_giou: 0.5990 (0.6176)  loss_ce_0: 0.6151 (0.6137)  loss_bbox_0: 0.1118 (0.0918)  loss_giou_0: 0.6005 (0.6183)  loss_ce_1: 0.6068 (0.6040)  loss_bbox_1: 0.1129 (0.0916)  loss_giou_1: 0.6012 (0.6160)  loss_ce_enc: 0.6151 (0.6286)  loss_bbox_enc: 0.1106 (0.0918)  loss_giou_enc: 0.6011 (0.6228)  loss_ce_unscaled: 0.6048 (0.6060)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0224 (0.0183)  loss_giou_unscaled: 0.2995 (0.3088)  cardinality_error_unscaled: 222.7500 (244.3415)  loss_ce_0_unscaled: 0.6151 (0.6137)  loss_bbox_0_unscaled: 0.0224 (0.0184)  loss_giou_0_unscaled: 0.3003 (0.3092)  cardinality_error_0_unscaled: 189.2500 (215.9329)  loss_ce_1_unscaled: 0.6068 (0.6040)  loss_bbox_1_unscaled: 0.0226 (0.0183)  loss_giou_1_unscaled: 0.3006 (0.3080)  cardinality_error_1_unscaled: 237.5000 (237.9268)  loss_ce_enc_unscaled: 0.6151 (0.6286)  loss_bbox_enc_unscaled: 0.0221 (0.0184)  loss_giou_enc_unscaled: 0.3006 (0.3114)  cardinality_error_enc_unscaled: 77.2500 (131.0915)  time: 1.6978  data: 0.0930
# Test:  [50/87]  eta: 0:01:02  class_error: 0.00  loss: 5.1524 (5.1325)  loss_ce: 0.5931 (0.5884)  loss_bbox: 0.1027 (0.0892)  loss_giou: 0.5878 (0.5982)  loss_ce_0: 0.5961 (0.5961)  loss_bbox_0: 0.1010 (0.0895)  loss_giou_0: 0.5874 (0.5985)  loss_ce_1: 0.5967 (0.5867)  loss_bbox_1: 0.1035 (0.0894)  loss_giou_1: 0.5904 (0.5969)  loss_ce_enc: 0.5954 (0.6077)  loss_bbox_enc: 0.0948 (0.0894)  loss_giou_enc: 0.5776 (0.6025)  loss_ce_unscaled: 0.5931 (0.5884)  class_error_unscaled: 0.0000 (1.9608)  loss_bbox_unscaled: 0.0205 (0.0178)  loss_giou_unscaled: 0.2939 (0.2991)  cardinality_error_unscaled: 221.2500 (242.5196)  loss_ce_0_unscaled: 0.5961 (0.5961)  loss_bbox_0_unscaled: 0.0202 (0.0179)  loss_giou_0_unscaled: 0.2937 (0.2993)  cardinality_error_0_unscaled: 180.0000 (212.1324)  loss_ce_1_unscaled: 0.5967 (0.5867)  loss_bbox_1_unscaled: 0.0207 (0.0179)  loss_giou_1_unscaled: 0.2952 (0.2984)  cardinality_error_1_unscaled: 213.0000 (233.9853)  loss_ce_enc_unscaled: 0.5954 (0.6077)  loss_bbox_enc_unscaled: 0.0190 (0.0179)  loss_giou_enc_unscaled: 0.2888 (0.3012)  cardinality_error_enc_unscaled: 77.2500 (124.7647)  time: 1.6281  data: 0.0876
# Test:  [60/87]  eta: 0:00:45  class_error: 0.00  loss: 4.8661 (5.1443)  loss_ce: 0.5732 (0.5927)  loss_bbox: 0.0771 (0.0890)  loss_giou: 0.5374 (0.5984)  loss_ce_0: 0.5839 (0.5987)  loss_bbox_0: 0.0792 (0.0891)  loss_giou_0: 0.5394 (0.5986)  loss_ce_1: 0.5721 (0.5915)  loss_bbox_1: 0.0772 (0.0892)  loss_giou_1: 0.5416 (0.5979)  loss_ce_enc: 0.5744 (0.6070)  loss_bbox_enc: 0.0784 (0.0897)  loss_giou_enc: 0.5551 (0.6026)  loss_ce_unscaled: 0.5732 (0.5927)  class_error_unscaled: 0.0000 (3.2787)  loss_bbox_unscaled: 0.0154 (0.0178)  loss_giou_unscaled: 0.2687 (0.2992)  cardinality_error_unscaled: 242.2500 (244.3893)  loss_ce_0_unscaled: 0.5839 (0.5987)  loss_bbox_0_unscaled: 0.0158 (0.0178)  loss_giou_0_unscaled: 0.2697 (0.2993)  cardinality_error_0_unscaled: 195.5000 (210.7459)  loss_ce_1_unscaled: 0.5721 (0.5915)  loss_bbox_1_unscaled: 0.0154 (0.0178)  loss_giou_1_unscaled: 0.2708 (0.2990)  cardinality_error_1_unscaled: 235.5000 (237.1475)  loss_ce_enc_unscaled: 0.5744 (0.6070)  loss_bbox_enc_unscaled: 0.0157 (0.0179)  loss_giou_enc_unscaled: 0.2776 (0.3013)  cardinality_error_enc_unscaled: 90.0000 (121.8115)  time: 1.6285  data: 0.0912
# Test:  [70/87]  eta: 0:00:28  class_error: 0.00  loss: 4.6354 (5.0017)  loss_ce: 0.5771 (0.5828)  loss_bbox: 0.0537 (0.0834)  loss_giou: 0.5105 (0.5769)  loss_ce_0: 0.5906 (0.5898)  loss_bbox_0: 0.0519 (0.0837)  loss_giou_0: 0.5178 (0.5781)  loss_ce_1: 0.5731 (0.5819)  loss_bbox_1: 0.0541 (0.0837)  loss_giou_1: 0.5136 (0.5765)  loss_ce_enc: 0.5744 (0.5975)  loss_bbox_enc: 0.0582 (0.0844)  loss_giou_enc: 0.5382 (0.5830)  loss_ce_unscaled: 0.5771 (0.5828)  class_error_unscaled: 0.0000 (2.8169)  loss_bbox_unscaled: 0.0107 (0.0167)  loss_giou_unscaled: 0.2553 (0.2884)  cardinality_error_unscaled: 271.0000 (248.3521)  loss_ce_0_unscaled: 0.5906 (0.5898)  loss_bbox_0_unscaled: 0.0104 (0.0167)  loss_giou_0_unscaled: 0.2589 (0.2890)  cardinality_error_0_unscaled: 233.7500 (216.7852)  loss_ce_1_unscaled: 0.5731 (0.5819)  loss_bbox_1_unscaled: 0.0108 (0.0167)  loss_giou_1_unscaled: 0.2568 (0.2883)  cardinality_error_1_unscaled: 256.0000 (240.2359)  loss_ce_enc_unscaled: 0.5744 (0.5975)  loss_bbox_enc_unscaled: 0.0116 (0.0169)  loss_giou_enc_unscaled: 0.2691 (0.2915)  cardinality_error_enc_unscaled: 121.2500 (129.2042)  time: 1.6249  data: 0.0889
# Test:  [80/87]  eta: 0:00:11  class_error: 0.00  loss: 4.3321 (4.9354)  loss_ce: 0.5432 (0.5775)  loss_bbox: 0.0481 (0.0804)  loss_giou: 0.4743 (0.5690)  loss_ce_0: 0.5538 (0.5843)  loss_bbox_0: 0.0486 (0.0806)  loss_giou_0: 0.4999 (0.5703)  loss_ce_1: 0.5419 (0.5766)  loss_bbox_1: 0.0484 (0.0806)  loss_giou_1: 0.4793 (0.5682)  loss_ce_enc: 0.5532 (0.5922)  loss_bbox_enc: 0.0479 (0.0812)  loss_giou_enc: 0.4891 (0.5745)  loss_ce_unscaled: 0.5432 (0.5775)  class_error_unscaled: 0.0000 (2.4691)  loss_bbox_unscaled: 0.0096 (0.0161)  loss_giou_unscaled: 0.2371 (0.2845)  cardinality_error_unscaled: 274.5000 (251.2747)  loss_ce_0_unscaled: 0.5538 (0.5843)  loss_bbox_0_unscaled: 0.0097 (0.0161)  loss_giou_0_unscaled: 0.2500 (0.2852)  cardinality_error_0_unscaled: 257.0000 (220.7377)  loss_ce_1_unscaled: 0.5419 (0.5766)  loss_bbox_1_unscaled: 0.0097 (0.0161)  loss_giou_1_unscaled: 0.2397 (0.2841)  cardinality_error_1_unscaled: 269.5000 (243.1358)  loss_ce_enc_unscaled: 0.5532 (0.5922)  loss_bbox_enc_unscaled: 0.0096 (0.0162)  loss_giou_enc_unscaled: 0.2445 (0.2873)  cardinality_error_enc_unscaled: 173.5000 (134.0802)  time: 1.6324  data: 0.0840
# Test:  [86/87]  eta: 0:00:01  class_error: 0.00  loss: 4.0308 (4.8691)  loss_ce: 0.4962 (0.5716)  loss_bbox: 0.0544 (0.0803)  loss_giou: 0.4173 (0.5580)  loss_ce_0: 0.5266 (0.5788)  loss_bbox_0: 0.0537 (0.0807)  loss_giou_0: 0.4230 (0.5593)  loss_ce_1: 0.4932 (0.5708)  loss_bbox_1: 0.0538 (0.0805)  loss_giou_1: 0.4156 (0.5572)  loss_ce_enc: 0.5401 (0.5868)  loss_bbox_enc: 0.0518 (0.0813)  loss_giou_enc: 0.4214 (0.5639)  loss_ce_unscaled: 0.4962 (0.5716)  class_error_unscaled: 0.0000 (2.2989)  loss_bbox_unscaled: 0.0109 (0.0161)  loss_giou_unscaled: 0.2087 (0.2790)  cardinality_error_unscaled: 263.0000 (250.7529)  loss_ce_0_unscaled: 0.5266 (0.5788)  loss_bbox_0_unscaled: 0.0107 (0.0161)  loss_giou_0_unscaled: 0.2115 (0.2796)  cardinality_error_0_unscaled: 233.7500 (220.7155)  loss_ce_1_unscaled: 0.4932 (0.5708)  loss_bbox_1_unscaled: 0.0108 (0.0161)  loss_giou_1_unscaled: 0.2078 (0.2786)  cardinality_error_1_unscaled: 250.2500 (242.7931)  loss_ce_enc_unscaled: 0.5401 (0.5868)  loss_bbox_enc_unscaled: 0.0104 (0.0163)  loss_giou_enc_unscaled: 0.2107 (0.2819)  cardinality_error_enc_unscaled: 131.2500 (129.8649)  time: 1.5880  data: 0.0808
# Test: Total time: 0:02:24 (1.6645 s / it)
# Averaged stats: class_error: 0.00  loss: 4.0308 (4.8691)  loss_ce: 0.4962 (0.5716)  loss_bbox: 0.0544 (0.0803)  loss_giou: 0.4173 (0.5580)  loss_ce_0: 0.5266 (0.5788)  loss_bbox_0: 0.0537 (0.0807)  loss_giou_0: 0.4230 (0.5593)  loss_ce_1: 0.4932 (0.5708)  loss_bbox_1: 0.0538 (0.0805)  loss_giou_1: 0.4156 (0.5572)  loss_ce_enc: 0.5401 (0.5868)  loss_bbox_enc: 0.0518 (0.0813)  loss_giou_enc: 0.4214 (0.5639)  loss_ce_unscaled: 0.4962 (0.5716)  class_error_unscaled: 0.0000 (2.2989)  loss_bbox_unscaled: 0.0109 (0.0161)  loss_giou_unscaled: 0.2087 (0.2790)  cardinality_error_unscaled: 263.0000 (250.7529)  loss_ce_0_unscaled: 0.5266 (0.5788)  loss_bbox_0_unscaled: 0.0107 (0.0161)  loss_giou_0_unscaled: 0.2115 (0.2796)  cardinality_error_0_unscaled: 233.7500 (220.7155)  loss_ce_1_unscaled: 0.4932 (0.5708)  loss_bbox_1_unscaled: 0.0108 (0.0161)  loss_giou_1_unscaled: 0.2078 (0.2786)  cardinality_error_1_unscaled: 250.2500 (242.7931)  loss_ce_enc_unscaled: 0.5401 (0.5868)  loss_bbox_enc_unscaled: 0.0104 (0.0163)  loss_giou_enc_unscaled: 0.2107 (0.2819)  cardinality_error_enc_unscaled: 131.2500 (129.8649)
# Accumulating evaluation results...
# DONE (t=0.75s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.444
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.916
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.253
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.506
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.617
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.348
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.337
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.579
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.673
# Test results: {'class_error': 2.2988505747126435, 'loss': 4.869142475622591, 'loss_ce': 0.5715500071636253, 'loss_bbox': 0.08029914666609518, 'loss_giou': 0.5579606544697422, 'loss_ce_0': 0.5787935407741776, 'loss_bbox_0': 0.08065425728758176, 'loss_giou_0': 0.5592835127622232, 'loss_ce_1': 0.5708251294461494, 'loss_bbox_1': 0.08054848783917126, 'loss_giou_1': 0.557206938321563, 'loss_ce_enc': 0.5868260310016922, 'loss_bbox_enc': 0.08131565909361703, 'loss_giou_enc': 0.563879114800486, 'loss_ce_unscaled': 0.5715500071636253, 'class_error_unscaled': 2.2988505747126435, 'loss_bbox_unscaled': 0.016059829430633235, 'loss_giou_unscaled': 0.2789803272348711, 'cardinality_error_unscaled': 250.7528735632184, 'loss_ce_0_unscaled': 0.5787935407741776, 'loss_bbox_0_unscaled': 0.01613085142111984, 'loss_giou_0_unscaled': 0.2796417563811116, 'cardinality_error_0_unscaled': 220.7155172413793, 'loss_ce_1_unscaled': 0.5708251294461494, 'loss_bbox_1_unscaled': 0.016109697606371737, 'loss_giou_1_unscaled': 0.2786034691607815, 'cardinality_error_1_unscaled': 242.79310344827587, 'loss_ce_enc_unscaled': 0.5868260310016922, 'loss_bbox_enc_unscaled': 0.016263131801595634, 'loss_giou_enc_unscaled': 0.281939557400243, 'cardinality_error_enc_unscaled': 129.86494252873564, 'results_json': {'class_map': [{'class': 'Gas-holes', 'map@50:95': 0.44607249377408625, 'map@50': 0.8948770136311233, 'precision': 0.9308510638297872, 'recall': 0.87}, {'class': 'shrinkage', 'map@50:95': 0.44258268403787776, 'map@50': 0.9379932211976693, 'precision': 0.9686609686609686, 'recall': 0.87}, {'class': 'all', 'map@50:95': 0.444327588905982, 'map@50': 0.9164351174143963, 'precision': 0.949756016245378, 'recall': 0.87}], 'map': 0.9164351174143963, 'precision': 0.949756016245378, 'recall': 0.87}, 'coco_eval_bbox': [0.444327588905982, 0.9164351174143963, 0.3407253972940214, 0.2530591476884327, 0.5061544695045838, 0.6166958312290857, 0.3484716494845361, 0.5074123711340206, 0.5172164948453609, 0.33736772486772487, 0.5792151162790697, 0.6729166666666667]}
# Results saved to D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\aicast_output/metrics_plot.png

# %%
from PIL import Image

Image.open("D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\aicast_output\\metrics_plot.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x1200>

# %%
model = RFDETRBase(pretrain_weights="D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\aicast_output\\checkpoint_best_total.pth")
# Out:
# Loading pretrain weights

# %%
import supervision as sv

DATASET_DIR = "D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\AlCastDetection-20251015T171832Z-1-001\\AlCastDetection"
OUTPUT_DIR = "D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\aicast_output"

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{DATASET_DIR}/test",
    annotations_path=f"{DATASET_DIR}/test/_annotations.coco.json",
)

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

model.optimize_for_inference()
targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    # Open and convert image to RGB (ensures 3 channels)
    image = Image.open(path).convert('RGB')  # This fixes the channel issue
    detections = model.predict(image, threshold=0)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:3638.)
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# 100%|██████████| 346/346 [02:42<00:00,  2.12it/s]

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])
