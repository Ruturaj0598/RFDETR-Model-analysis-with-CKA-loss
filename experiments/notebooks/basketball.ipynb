# %%
import os

os.environ["ROBOFLOW_API_KEY"] = "J1oKKy8ww5yYkJGO3YUZ"

# %%
# !nvidia-smi
# Out:
# Sun Oct 12 01:44:14 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 572.70                 Driver Version: 572.70         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2060      WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   47C    P8             12W /  100W |     553MiB /   6144MiB |     21%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A             204    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A            1064    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A            1448    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A            5692    C+G   ...SnippingTool\SnippingTool.exe      N/A      |
# |    0   N/A  N/A            6032    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A            9512    C+G   ...ata\Roaming\Zoom\bin\Zoom.exe      N/A      |
# |    0   N/A  N/A           11020    C+G   ...al AntiVirus Pro\onlinent.exe      N/A      |
# |    0   N/A  N/A           12776    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           13860    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           14836    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           15284    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           16764    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           18656    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           20052    C+G   ...enCommandCenterBackground.exe      N/A      |
# |    0   N/A  N/A           20380    C+G   ...0_x64__8j3eq9eme6ctt\IGCC.exe      N/A      |
# |    0   N/A  N/A           20624    C+G   ....0.3485.81\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           21060    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           24016    C+G   ....0.3485.81\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           28076    C+G   ....0.3485.81\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           29060    C+G   ...HP.Omen.OmenCommandCenter.exe      N/A      |
# |    0   N/A  N/A           40848    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           45764    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           49560    C+G   ....0.3537.57\msedgewebview2.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import numpy as np
import supervision as sv

from PIL import Image

from rfdetr import RFDETRMedium
from rfdetr.util.coco_classes import COCO_CLASSES

image = Image.open("D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\dog-2.jpeg")

model = RFDETRMedium(resolution=640)


detections = model.predict(image, threshold=0.5)

color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])
text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(color=color, thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    smart_position=True
)

labels = [
    f"{COCO_CLASSES[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = bbox_annotator.annotate(annotated_image, detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)
annotated_image.thumbnail((800, 800))
annotated_image
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# Model is not optimized for inference. Latency may be higher than expected. You can optimize the model for inference by calling model.optimize_for_inference().
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:3638.)
# <PIL.Image.Image image mode=RGB size=450x800>

# %%
from rfdetr import RFDETRBase

model = RFDETRBase()

DATASET_DIR = "D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\basketball-player-detection-2.v13i.coco"
OUTPUT_DIR = "D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\basketball_output"
EPOCHS = 50
BATCH_SIZE = 4  # Adjust based on GPU memory (T4: 4, A100: 16)
GRAD_ACCUM_STEPS = 16  # Keep total batch size = batch_size * grad_accum_steps = 16
LEARNING_RATE = 1e-4

# Create output directory
os.makedirs(OUTPUT_DIR, exist_ok=True)

# History callback to track metrics
history = []

def callback_on_epoch_end(data):
    """Callback function to store training metrics"""
    history.append(data)
    print(f"Epoch {data.get('epoch', 0)}: Train Loss = {data.get('train_loss', 0):.4f}, "
          f"Val Loss = {data.get('test_loss', 0):.4f}, mAP = {data.get('test_map', 0):.4f}")

# Register callback
model.callbacks["on_fit_epoch_end"].append(callback_on_epoch_end)

print("Model initialized and ready for training!")
print(f"Dataset: {DATASET_DIR}")
print(f"Output: {OUTPUT_DIR}")
print(f"Epochs: {EPOCHS}, Batch Size: {BATCH_SIZE}, Grad Accum: {GRAD_ACCUM_STEPS}")

model.train(
    dataset_dir=DATASET_DIR,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    grad_accum_steps=GRAD_ACCUM_STEPS,
    lr=LEARNING_RATE,
    output_dir=OUTPUT_DIR,
    use_ema=True,  # Use Exponential Moving Average for better generalization
    tensorboard=False,  # Set to True if you want TensorBoard logging
    early_stopping=True,  # Enable early stopping
    early_stopping_patience=10,  # Stop if no improvement for 10 epochs
    amp=False,  # **CRITICAL: Disable AMP for CPU training**
    device='cpu',  # Explicitly set device to CPU
    num_workers=0,  # Set to 0 for CPU to avoid multiprocessing issues
    multi_scale=False,  # Disable multi-scale training to avoid inference tensors error
    resolution=448,
)
# Out:
# Loading pretrain weights
# Model initialized and ready for training!
# Dataset: D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\basketball-player-detection-2.v13i.coco
# Output: D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\basketball_output
# Epochs: 50, Batch Size: 4, Grad Accum: 16
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=6, grad_accum_steps=16, amp=False, lr=0.0001, lr_encoder=0.00015, batch_size=4, weight_decay=0.0001, epochs=50, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-base.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\basketball-player-detection-2.v13i.coco', square_resize_div_64=True, output_dir='D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\basketball_output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=0, device='cpu', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=448, use_cls_token=False, multi_scale=False, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0.0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=14, num_windows=4, positional_encoding_size=37, mask_downsample_ratio=4, tensorboard=False, wandb=False, project=None, run=None, class_names=['ball', 'number', 'player', 'referee', 'rim'], run_test=True, segmentation_head=False, distributed=False)
# number of params: 31868700
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  16
# Total batch size:  64
# LENGTH OF DATA LOADER: 16
# Epoch: [0]  [ 0/16]  eta: 0:41:13  lr: 0.000100  class_error: 94.20  loss: 9.5752 (9.5752)  loss_ce: 1.1585 (1.1585)  loss_bbox: 0.2707 (0.2707)  loss_giou: 0.9428 (0.9428)  loss_ce_0: 1.1821 (1.1821)  loss_bbox_0: 0.2782 (0.2782)  loss_giou_0: 0.9487 (0.9487)  loss_ce_1: 1.1640 (1.1640)  loss_bbox_1: 0.2606 (0.2606)  loss_giou_1: 0.9367 (0.9367)  loss_ce_enc: 1.1692 (1.1692)  loss_bbox_enc: 0.2958 (0.2958)  loss_giou_enc: 0.9678 (0.9678)  loss_ce_unscaled: 1.1585 (1.1585)  class_error_unscaled: 94.2029 (94.2029)  loss_bbox_unscaled: 0.0541 (0.0541)  loss_giou_unscaled: 0.4714 (0.4714)  cardinality_error_unscaled: 3882.2500 (3882.2500)  loss_ce_0_unscaled: 1.1821 (1.1821)  loss_bbox_0_unscaled: 0.0556 (0.0556)  loss_giou_0_unscaled: 0.4743 (0.4743)  cardinality_error_0_unscaled: 3882.7500 (3882.7500)  loss_ce_1_unscaled: 1.1640 (1.1640)  loss_bbox_1_unscaled: 0.0521 (0.0521)  loss_giou_1_unscaled: 0.4683 (0.4683)  cardinality_error_1_unscaled: 3882.7500 (3882.7500)  loss_ce_enc_unscaled: 1.1692 (1.1692)  loss_bbox_enc_unscaled: 0.0592 (0.0592)  loss_giou_enc_unscaled: 0.4839 (0.4839)  cardinality_error_enc_unscaled: 3882.7500 (3882.7500)  time: 154.6095  data: 1.0197
# Epoch: [0]  [10/16]  eta: 0:13:45  lr: 0.000100  class_error: 23.08  loss: 7.4158 (7.5642)  loss_ce: 0.8062 (0.8613)  loss_bbox: 0.2154 (0.2119)  loss_giou: 0.7956 (0.7893)  loss_ce_0: 0.8876 (0.8922)  loss_bbox_0: 0.2072 (0.2149)  loss_giou_0: 0.8110 (0.7983)  loss_ce_1: 0.8002 (0.8564)  loss_bbox_1: 0.1997 (0.2096)  loss_giou_1: 0.8227 (0.7972)  loss_ce_enc: 0.8463 (0.8712)  loss_bbox_enc: 0.2277 (0.2366)  loss_giou_enc: 0.8396 (0.8252)  loss_ce_unscaled: 0.8062 (0.8613)  class_error_unscaled: 45.8420 (52.1454)  loss_bbox_unscaled: 0.0431 (0.0424)  loss_giou_unscaled: 0.3978 (0.3946)  cardinality_error_unscaled: 3868.2500 (3862.3182)  loss_ce_0_unscaled: 0.8876 (0.8922)  loss_bbox_0_unscaled: 0.0414 (0.0430)  loss_giou_0_unscaled: 0.4055 (0.3992)  cardinality_error_0_unscaled: 3881.5000 (3878.2955)  loss_ce_1_unscaled: 0.8002 (0.8564)  loss_bbox_1_unscaled: 0.0399 (0.0419)  loss_giou_1_unscaled: 0.4113 (0.3986)  cardinality_error_1_unscaled: 3875.7500 (3870.7273)  loss_ce_enc_unscaled: 0.8463 (0.8712)  loss_bbox_enc_unscaled: 0.0455 (0.0473)  loss_giou_enc_unscaled: 0.4198 (0.4126)  cardinality_error_enc_unscaled: 3874.7500 (3869.7727)  time: 137.6423  data: 0.9299
# Epoch: [0]  [15/16]  eta: 0:02:16  lr: 0.000100  class_error: 15.38  loss: 6.6181 (7.1029)  loss_ce: 0.7686 (0.8173)  loss_bbox: 0.1794 (0.1895)  loss_giou: 0.6746 (0.7431)  loss_ce_0: 0.8053 (0.8402)  loss_bbox_0: 0.1667 (0.1912)  loss_giou_0: 0.6865 (0.7508)  loss_ce_1: 0.7637 (0.8167)  loss_bbox_1: 0.1802 (0.1881)  loss_giou_1: 0.6803 (0.7503)  loss_ce_enc: 0.8010 (0.8294)  loss_bbox_enc: 0.1940 (0.2092)  loss_giou_enc: 0.6871 (0.7772)  loss_ce_unscaled: 0.7686 (0.8173)  class_error_unscaled: 30.4248 (42.2173)  loss_bbox_unscaled: 0.0359 (0.0379)  loss_giou_unscaled: 0.3373 (0.3716)  cardinality_error_unscaled: 3855.5000 (3799.8750)  loss_ce_0_unscaled: 0.8053 (0.8402)  loss_bbox_0_unscaled: 0.0333 (0.0382)  loss_giou_0_unscaled: 0.3432 (0.3754)  cardinality_error_0_unscaled: 3880.0000 (3856.8438)  loss_ce_1_unscaled: 0.7637 (0.8167)  loss_bbox_1_unscaled: 0.0360 (0.0376)  loss_giou_1_unscaled: 0.3401 (0.3752)  cardinality_error_1_unscaled: 3866.2500 (3821.8594)  loss_ce_enc_unscaled: 0.8010 (0.8294)  loss_bbox_enc_unscaled: 0.0388 (0.0418)  loss_giou_enc_unscaled: 0.3435 (0.3886)  cardinality_error_enc_unscaled: 3859.2500 (3829.3125)  time: 136.6881  data: 0.9155
# Epoch: [0] Total time: 0:36:27 (136.6903 s / it)
# Averaged stats: lr: 0.000100  class_error: 15.38  loss: 6.6181 (7.1029)  loss_ce: 0.7686 (0.8173)  loss_bbox: 0.1794 (0.1895)  loss_giou: 0.6746 (0.7431)  loss_ce_0: 0.8053 (0.8402)  loss_bbox_0: 0.1667 (0.1912)  loss_giou_0: 0.6865 (0.7508)  loss_ce_1: 0.7637 (0.8167)  loss_bbox_1: 0.1802 (0.1881)  loss_giou_1: 0.6803 (0.7503)  loss_ce_enc: 0.8010 (0.8294)  loss_bbox_enc: 0.1940 (0.2092)  loss_giou_enc: 0.6871 (0.7772)  loss_ce_unscaled: 0.7686 (0.8173)  class_error_unscaled: 30.4248 (42.2173)  loss_bbox_unscaled: 0.0359 (0.0379)  loss_giou_unscaled: 0.3373 (0.3716)  cardinality_error_unscaled: 3855.5000 (3799.8750)  loss_ce_0_unscaled: 0.8053 (0.8402)  loss_bbox_0_unscaled: 0.0333 (0.0382)  loss_giou_0_unscaled: 0.3432 (0.3754)  cardinality_error_0_unscaled: 3880.0000 (3856.8438)  loss_ce_1_unscaled: 0.7637 (0.8167)  loss_bbox_1_unscaled: 0.0360 (0.0376)  loss_giou_1_unscaled: 0.3401 (0.3752)  cardinality_error_1_unscaled: 3866.2500 (3821.8594)  loss_ce_enc_unscaled: 0.8010 (0.8294)  loss_bbox_enc_unscaled: 0.0388 (0.0418)  loss_giou_enc_unscaled: 0.3435 (0.3886)  cardinality_error_enc_unscaled: 3859.2500 (3829.3125)
# Test:  [ 0/47]  eta: 0:01:23  class_error: 16.00  loss: 5.9865 (5.9865)  loss_ce: 0.6219 (0.6219)  loss_bbox: 0.1354 (0.1354)  loss_giou: 0.7174 (0.7174)  loss_ce_0: 0.6565 (0.6565)  loss_bbox_0: 0.1283 (0.1283)  loss_giou_0: 0.7092 (0.7092)  loss_ce_1: 0.6341 (0.6341)  loss_bbox_1: 0.1328 (0.1328)  loss_giou_1: 0.7046 (0.7046)  loss_ce_enc: 0.6482 (0.6482)  loss_bbox_enc: 0.1562 (0.1562)  loss_giou_enc: 0.7417 (0.7417)  loss_ce_unscaled: 0.6219 (0.6219)  class_error_unscaled: 16.0000 (16.0000)  loss_bbox_unscaled: 0.0271 (0.0271)  loss_giou_unscaled: 0.3587 (0.3587)  cardinality_error_unscaled: 236.2500 (236.2500)  loss_ce_0_unscaled: 0.6565 (0.6565)  loss_bbox_0_unscaled: 0.0257 (0.0257)  loss_giou_0_unscaled: 0.3546 (0.3546)  cardinality_error_0_unscaled: 265.0000 (265.0000)  loss_ce_1_unscaled: 0.6341 (0.6341)  loss_bbox_1_unscaled: 0.0266 (0.0266)  loss_giou_1_unscaled: 0.3523 (0.3523)  cardinality_error_1_unscaled: 245.7500 (245.7500)  loss_ce_enc_unscaled: 0.6482 (0.6482)  loss_bbox_enc_unscaled: 0.0312 (0.0312)  loss_giou_enc_unscaled: 0.3709 (0.3709)  cardinality_error_enc_unscaled: 257.0000 (257.0000)  time: 1.7722  data: 0.1564
# Test:  [10/47]  eta: 0:00:54  class_error: 10.67  loss: 6.0691 (6.0310)  loss_ce: 0.6869 (0.6801)  loss_bbox: 0.1354 (0.1398)  loss_giou: 0.6752 (0.6647)  loss_ce_0: 0.7051 (0.7032)  loss_bbox_0: 0.1436 (0.1424)  loss_giou_0: 0.6588 (0.6615)  loss_ce_1: 0.6898 (0.6914)  loss_bbox_1: 0.1384 (0.1420)  loss_giou_1: 0.6698 (0.6648)  loss_ce_enc: 0.7114 (0.7112)  loss_bbox_enc: 0.1522 (0.1499)  loss_giou_enc: 0.6985 (0.6798)  loss_ce_unscaled: 0.6869 (0.6801)  class_error_unscaled: 16.0000 (15.2034)  loss_bbox_unscaled: 0.0271 (0.0280)  loss_giou_unscaled: 0.3376 (0.3324)  cardinality_error_unscaled: 236.2500 (234.1364)  loss_ce_0_unscaled: 0.7051 (0.7032)  loss_bbox_0_unscaled: 0.0287 (0.0285)  loss_giou_0_unscaled: 0.3294 (0.3308)  cardinality_error_0_unscaled: 263.7500 (265.0682)  loss_ce_1_unscaled: 0.6898 (0.6914)  loss_bbox_1_unscaled: 0.0277 (0.0284)  loss_giou_1_unscaled: 0.3349 (0.3324)  cardinality_error_1_unscaled: 245.7500 (246.1591)  loss_ce_enc_unscaled: 0.7114 (0.7112)  loss_bbox_enc_unscaled: 0.0304 (0.0300)  loss_giou_enc_unscaled: 0.3492 (0.3399)  cardinality_error_enc_unscaled: 257.0000 (256.8636)  time: 1.4811  data: 0.0580
# Test:  [20/47]  eta: 0:00:39  class_error: 18.52  loss: 6.0691 (6.0150)  loss_ce: 0.6887 (0.6841)  loss_bbox: 0.1316 (0.1384)  loss_giou: 0.6655 (0.6561)  loss_ce_0: 0.7051 (0.7046)  loss_bbox_0: 0.1369 (0.1420)  loss_giou_0: 0.6556 (0.6577)  loss_ce_1: 0.6936 (0.6950)  loss_bbox_1: 0.1356 (0.1405)  loss_giou_1: 0.6599 (0.6554)  loss_ce_enc: 0.7135 (0.7146)  loss_bbox_enc: 0.1492 (0.1493)  loss_giou_enc: 0.6901 (0.6772)  loss_ce_unscaled: 0.6887 (0.6841)  class_error_unscaled: 16.4179 (16.0232)  loss_bbox_unscaled: 0.0263 (0.0277)  loss_giou_unscaled: 0.3327 (0.3281)  cardinality_error_unscaled: 231.0000 (232.7262)  loss_ce_0_unscaled: 0.7051 (0.7046)  loss_bbox_0_unscaled: 0.0274 (0.0284)  loss_giou_0_unscaled: 0.3278 (0.3288)  cardinality_error_0_unscaled: 263.7500 (264.8690)  loss_ce_1_unscaled: 0.6936 (0.6950)  loss_bbox_1_unscaled: 0.0271 (0.0281)  loss_giou_1_unscaled: 0.3299 (0.3277)  cardinality_error_1_unscaled: 244.5000 (244.6548)  loss_ce_enc_unscaled: 0.7135 (0.7146)  loss_bbox_enc_unscaled: 0.0298 (0.0299)  loss_giou_enc_unscaled: 0.3451 (0.3386)  cardinality_error_enc_unscaled: 256.7500 (256.3810)  time: 1.4521  data: 0.0480
# Test:  [30/47]  eta: 0:00:24  class_error: 12.00  loss: 6.0641 (6.0260)  loss_ce: 0.6922 (0.6880)  loss_bbox: 0.1325 (0.1391)  loss_giou: 0.6497 (0.6531)  loss_ce_0: 0.7114 (0.7087)  loss_bbox_0: 0.1357 (0.1424)  loss_giou_0: 0.6641 (0.6567)  loss_ce_1: 0.7034 (0.6989)  loss_bbox_1: 0.1334 (0.1412)  loss_giou_1: 0.6514 (0.6537)  loss_ce_enc: 0.7228 (0.7171)  loss_bbox_enc: 0.1482 (0.1500)  loss_giou_enc: 0.6901 (0.6771)  loss_ce_unscaled: 0.6922 (0.6880)  class_error_unscaled: 16.4384 (16.1856)  loss_bbox_unscaled: 0.0265 (0.0278)  loss_giou_unscaled: 0.3249 (0.3266)  cardinality_error_unscaled: 228.2500 (231.6532)  loss_ce_0_unscaled: 0.7114 (0.7087)  loss_bbox_0_unscaled: 0.0271 (0.0285)  loss_giou_0_unscaled: 0.3320 (0.3283)  cardinality_error_0_unscaled: 263.7500 (264.8871)  loss_ce_1_unscaled: 0.7034 (0.6989)  loss_bbox_1_unscaled: 0.0267 (0.0282)  loss_giou_1_unscaled: 0.3257 (0.3268)  cardinality_error_1_unscaled: 240.7500 (243.8952)  loss_ce_enc_unscaled: 0.7228 (0.7171)  loss_bbox_enc_unscaled: 0.0296 (0.0300)  loss_giou_enc_unscaled: 0.3451 (0.3386)  cardinality_error_enc_unscaled: 256.0000 (255.7419)  time: 1.4510  data: 0.0473
# Test:  [40/47]  eta: 0:00:10  class_error: 20.63  loss: 6.0457 (6.0364)  loss_ce: 0.6947 (0.6911)  loss_bbox: 0.1312 (0.1391)  loss_giou: 0.6479 (0.6532)  loss_ce_0: 0.7114 (0.7094)  loss_bbox_0: 0.1337 (0.1422)  loss_giou_0: 0.6647 (0.6583)  loss_ce_1: 0.7102 (0.7008)  loss_bbox_1: 0.1284 (0.1408)  loss_giou_1: 0.6472 (0.6538)  loss_ce_enc: 0.7207 (0.7170)  loss_bbox_enc: 0.1451 (0.1494)  loss_giou_enc: 0.6747 (0.6813)  loss_ce_unscaled: 0.6947 (0.6911)  class_error_unscaled: 15.6250 (16.4478)  loss_bbox_unscaled: 0.0262 (0.0278)  loss_giou_unscaled: 0.3240 (0.3266)  cardinality_error_unscaled: 227.7500 (231.7988)  loss_ce_0_unscaled: 0.7114 (0.7094)  loss_bbox_0_unscaled: 0.0267 (0.0284)  loss_giou_0_unscaled: 0.3324 (0.3291)  cardinality_error_0_unscaled: 265.2500 (265.1585)  loss_ce_1_unscaled: 0.7102 (0.7008)  loss_bbox_1_unscaled: 0.0257 (0.0282)  loss_giou_1_unscaled: 0.3236 (0.3269)  cardinality_error_1_unscaled: 242.0000 (244.0122)  loss_ce_enc_unscaled: 0.7207 (0.7170)  loss_bbox_enc_unscaled: 0.0290 (0.0299)  loss_giou_enc_unscaled: 0.3373 (0.3407)  cardinality_error_enc_unscaled: 256.5000 (255.9268)  time: 1.4487  data: 0.0480
# Test:  [46/47]  eta: 0:00:01  class_error: 15.15  loss: 6.0457 (6.0397)  loss_ce: 0.6892 (0.6901)  loss_bbox: 0.1305 (0.1378)  loss_giou: 0.6485 (0.6568)  loss_ce_0: 0.7078 (0.7106)  loss_bbox_0: 0.1365 (0.1404)  loss_giou_0: 0.6647 (0.6598)  loss_ce_1: 0.6963 (0.6998)  loss_bbox_1: 0.1331 (0.1394)  loss_giou_1: 0.6558 (0.6569)  loss_ce_enc: 0.7162 (0.7173)  loss_bbox_enc: 0.1420 (0.1477)  loss_giou_enc: 0.6747 (0.6831)  loss_ce_unscaled: 0.6892 (0.6901)  class_error_unscaled: 15.1515 (16.2503)  loss_bbox_unscaled: 0.0261 (0.0276)  loss_giou_unscaled: 0.3243 (0.3284)  cardinality_error_unscaled: 229.7500 (231.5745)  loss_ce_0_unscaled: 0.7078 (0.7106)  loss_bbox_0_unscaled: 0.0273 (0.0281)  loss_giou_0_unscaled: 0.3324 (0.3299)  cardinality_error_0_unscaled: 265.2500 (264.8830)  loss_ce_1_unscaled: 0.6963 (0.6998)  loss_bbox_1_unscaled: 0.0266 (0.0279)  loss_giou_1_unscaled: 0.3279 (0.3284)  cardinality_error_1_unscaled: 242.0000 (243.7979)  loss_ce_enc_unscaled: 0.7162 (0.7173)  loss_bbox_enc_unscaled: 0.0284 (0.0295)  loss_giou_enc_unscaled: 0.3373 (0.3415)  cardinality_error_enc_unscaled: 256.5000 (255.7872)  time: 1.4170  data: 0.0468
# Test: Total time: 0:01:07 (1.4442 s / it)
# Averaged stats: class_error: 15.15  loss: 6.0457 (6.0397)  loss_ce: 0.6892 (0.6901)  loss_bbox: 0.1305 (0.1378)  loss_giou: 0.6485 (0.6568)  loss_ce_0: 0.7078 (0.7106)  loss_bbox_0: 0.1365 (0.1404)  loss_giou_0: 0.6647 (0.6598)  loss_ce_1: 0.6963 (0.6998)  loss_bbox_1: 0.1331 (0.1394)  loss_giou_1: 0.6558 (0.6569)  loss_ce_enc: 0.7162 (0.7173)  loss_bbox_enc: 0.1420 (0.1477)  loss_giou_enc: 0.6747 (0.6831)  loss_ce_unscaled: 0.6892 (0.6901)  class_error_unscaled: 15.1515 (16.2503)  loss_bbox_unscaled: 0.0261 (0.0276)  loss_giou_unscaled: 0.3243 (0.3284)  cardinality_error_unscaled: 229.7500 (231.5745)  loss_ce_0_unscaled: 0.7078 (0.7106)  loss_bbox_0_unscaled: 0.0273 (0.0281)  loss_giou_0_unscaled: 0.3324 (0.3299)  cardinality_error_0_unscaled: 265.2500 (264.8830)  loss_ce_1_unscaled: 0.6963 (0.6998)  loss_bbox_1_unscaled: 0.0266 (0.0279)  loss_giou_1_unscaled: 0.3279 (0.3284)  cardinality_error_1_unscaled: 242.0000 (243.7979)  loss_ce_enc_unscaled: 0.7162 (0.7173)  loss_bbox_enc_unscaled: 0.0284 (0.0295)  loss_giou_enc_unscaled: 0.3373 (0.3415)  cardinality_error_enc_unscaled: 256.5000 (255.7872)
# Accumulating evaluation results...
# DONE (t=0.34s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.356
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.231
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.519
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.341
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.684
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.640
# Test:  [ 0/47]  eta: 0:01:21  class_error: 16.00  loss: 5.9778 (5.9778)  loss_ce: 0.6253 (0.6253)  loss_bbox: 0.1303 (0.1303)  loss_giou: 0.7144 (0.7144)  loss_ce_0: 0.6580 (0.6580)  loss_bbox_0: 0.1268 (0.1268)  loss_giou_0: 0.7073 (0.7073)  loss_ce_1: 0.6315 (0.6315)  loss_bbox_1: 0.1293 (0.1293)  loss_giou_1: 0.7074 (0.7074)  loss_ce_enc: 0.6484 (0.6484)  loss_bbox_enc: 0.1566 (0.1566)  loss_giou_enc: 0.7425 (0.7425)  loss_ce_unscaled: 0.6253 (0.6253)  class_error_unscaled: 16.0000 (16.0000)  loss_bbox_unscaled: 0.0261 (0.0261)  loss_giou_unscaled: 0.3572 (0.3572)  cardinality_error_unscaled: 239.0000 (239.0000)  loss_ce_0_unscaled: 0.6580 (0.6580)  loss_bbox_0_unscaled: 0.0254 (0.0254)  loss_giou_0_unscaled: 0.3536 (0.3536)  cardinality_error_0_unscaled: 266.5000 (266.5000)  loss_ce_1_unscaled: 0.6315 (0.6315)  loss_bbox_1_unscaled: 0.0259 (0.0259)  loss_giou_1_unscaled: 0.3537 (0.3537)  cardinality_error_1_unscaled: 248.7500 (248.7500)  loss_ce_enc_unscaled: 0.6484 (0.6484)  loss_bbox_enc_unscaled: 0.0313 (0.0313)  loss_giou_enc_unscaled: 0.3712 (0.3712)  cardinality_error_enc_unscaled: 258.5000 (258.5000)  time: 1.7308  data: 0.0502
# Test:  [10/47]  eta: 0:01:00  class_error: 10.67  loss: 6.0677 (6.0359)  loss_ce: 0.6890 (0.6811)  loss_bbox: 0.1328 (0.1392)  loss_giou: 0.6720 (0.6651)  loss_ce_0: 0.7048 (0.7044)  loss_bbox_0: 0.1444 (0.1424)  loss_giou_0: 0.6585 (0.6609)  loss_ce_1: 0.6909 (0.6923)  loss_bbox_1: 0.1387 (0.1413)  loss_giou_1: 0.6727 (0.6671)  loss_ce_enc: 0.7124 (0.7128)  loss_bbox_enc: 0.1522 (0.1497)  loss_giou_enc: 0.6993 (0.6794)  loss_ce_unscaled: 0.6890 (0.6811)  class_error_unscaled: 16.0000 (16.0100)  loss_bbox_unscaled: 0.0266 (0.0278)  loss_giou_unscaled: 0.3360 (0.3325)  cardinality_error_unscaled: 239.0000 (236.7500)  loss_ce_0_unscaled: 0.7048 (0.7044)  loss_bbox_0_unscaled: 0.0289 (0.0285)  loss_giou_0_unscaled: 0.3293 (0.3305)  cardinality_error_0_unscaled: 265.0000 (266.2727)  loss_ce_1_unscaled: 0.6909 (0.6923)  loss_bbox_1_unscaled: 0.0277 (0.0283)  loss_giou_1_unscaled: 0.3363 (0.3335)  cardinality_error_1_unscaled: 248.7500 (248.2727)  loss_ce_enc_unscaled: 0.7124 (0.7128)  loss_bbox_enc_unscaled: 0.0304 (0.0299)  loss_giou_enc_unscaled: 0.3496 (0.3397)  cardinality_error_enc_unscaled: 258.5000 (258.0227)  time: 1.6216  data: 0.0451
# Test:  [20/47]  eta: 0:00:43  class_error: 16.67  loss: 6.0677 (6.0186)  loss_ce: 0.6890 (0.6849)  loss_bbox: 0.1334 (0.1387)  loss_giou: 0.6615 (0.6563)  loss_ce_0: 0.7057 (0.7066)  loss_bbox_0: 0.1355 (0.1417)  loss_giou_0: 0.6548 (0.6554)  loss_ce_1: 0.6964 (0.6956)  loss_bbox_1: 0.1375 (0.1401)  loss_giou_1: 0.6594 (0.6575)  loss_ce_enc: 0.7168 (0.7163)  loss_bbox_enc: 0.1489 (0.1492)  loss_giou_enc: 0.6907 (0.6762)  loss_ce_unscaled: 0.6890 (0.6849)  class_error_unscaled: 16.2162 (16.3873)  loss_bbox_unscaled: 0.0267 (0.0277)  loss_giou_unscaled: 0.3308 (0.3281)  cardinality_error_unscaled: 233.0000 (235.3929)  loss_ce_0_unscaled: 0.7057 (0.7066)  loss_bbox_0_unscaled: 0.0271 (0.0283)  loss_giou_0_unscaled: 0.3274 (0.3277)  cardinality_error_0_unscaled: 264.7500 (265.9405)  loss_ce_1_unscaled: 0.6964 (0.6956)  loss_bbox_1_unscaled: 0.0275 (0.0280)  loss_giou_1_unscaled: 0.3297 (0.3287)  cardinality_error_1_unscaled: 245.0000 (246.9405)  loss_ce_enc_unscaled: 0.7168 (0.7163)  loss_bbox_enc_unscaled: 0.0298 (0.0298)  loss_giou_enc_unscaled: 0.3453 (0.3381)  cardinality_error_enc_unscaled: 257.2500 (257.5476)  time: 1.6139  data: 0.0438
# Test:  [30/47]  eta: 0:00:27  class_error: 13.33  loss: 6.0624 (6.0296)  loss_ce: 0.6935 (0.6890)  loss_bbox: 0.1334 (0.1396)  loss_giou: 0.6499 (0.6531)  loss_ce_0: 0.7117 (0.7103)  loss_bbox_0: 0.1339 (0.1420)  loss_giou_0: 0.6593 (0.6553)  loss_ce_1: 0.7024 (0.6998)  loss_bbox_1: 0.1347 (0.1408)  loss_giou_1: 0.6538 (0.6551)  loss_ce_enc: 0.7244 (0.7186)  loss_bbox_enc: 0.1477 (0.1492)  loss_giou_enc: 0.6907 (0.6769)  loss_ce_unscaled: 0.6935 (0.6890)  class_error_unscaled: 16.4179 (16.5232)  loss_bbox_unscaled: 0.0267 (0.0279)  loss_giou_unscaled: 0.3249 (0.3265)  cardinality_error_unscaled: 231.7500 (234.2500)  loss_ce_0_unscaled: 0.7117 (0.7103)  loss_bbox_0_unscaled: 0.0268 (0.0284)  loss_giou_0_unscaled: 0.3296 (0.3276)  cardinality_error_0_unscaled: 264.2500 (265.9032)  loss_ce_1_unscaled: 0.7024 (0.6998)  loss_bbox_1_unscaled: 0.0269 (0.0282)  loss_giou_1_unscaled: 0.3269 (0.3275)  cardinality_error_1_unscaled: 244.0000 (246.1855)  loss_ce_enc_unscaled: 0.7244 (0.7186)  loss_bbox_enc_unscaled: 0.0295 (0.0298)  loss_giou_enc_unscaled: 0.3453 (0.3384)  cardinality_error_enc_unscaled: 257.2500 (256.9355)  time: 1.5949  data: 0.0431
# Test:  [40/47]  eta: 0:00:11  class_error: 20.63  loss: 6.0551 (6.0406)  loss_ce: 0.6969 (0.6921)  loss_bbox: 0.1318 (0.1397)  loss_giou: 0.6491 (0.6534)  loss_ce_0: 0.7117 (0.7105)  loss_bbox_0: 0.1312 (0.1420)  loss_giou_0: 0.6673 (0.6576)  loss_ce_1: 0.7113 (0.7018)  loss_bbox_1: 0.1281 (0.1407)  loss_giou_1: 0.6529 (0.6547)  loss_ce_enc: 0.7217 (0.7185)  loss_bbox_enc: 0.1454 (0.1486)  loss_giou_enc: 0.6753 (0.6809)  loss_ce_unscaled: 0.6969 (0.6921)  class_error_unscaled: 17.3333 (16.8099)  loss_bbox_unscaled: 0.0264 (0.0279)  loss_giou_unscaled: 0.3246 (0.3267)  cardinality_error_unscaled: 230.5000 (234.5000)  loss_ce_0_unscaled: 0.7117 (0.7105)  loss_bbox_0_unscaled: 0.0262 (0.0284)  loss_giou_0_unscaled: 0.3337 (0.3288)  cardinality_error_0_unscaled: 266.7500 (266.2195)  loss_ce_1_unscaled: 0.7113 (0.7018)  loss_bbox_1_unscaled: 0.0256 (0.0281)  loss_giou_1_unscaled: 0.3265 (0.3273)  cardinality_error_1_unscaled: 244.2500 (246.2073)  loss_ce_enc_unscaled: 0.7217 (0.7185)  loss_bbox_enc_unscaled: 0.0291 (0.0297)  loss_giou_enc_unscaled: 0.3376 (0.3404)  cardinality_error_enc_unscaled: 257.7500 (257.0915)  time: 1.5664  data: 0.0434
# Test:  [46/47]  eta: 0:00:01  class_error: 15.15  loss: 6.0551 (6.0443)  loss_ce: 0.6902 (0.6911)  loss_bbox: 0.1312 (0.1385)  loss_giou: 0.6440 (0.6571)  loss_ce_0: 0.7044 (0.7116)  loss_bbox_0: 0.1358 (0.1404)  loss_giou_0: 0.6673 (0.6589)  loss_ce_1: 0.6988 (0.7008)  loss_bbox_1: 0.1332 (0.1396)  loss_giou_1: 0.6517 (0.6576)  loss_ce_enc: 0.7172 (0.7189)  loss_bbox_enc: 0.1422 (0.1471)  loss_giou_enc: 0.6753 (0.6826)  loss_ce_unscaled: 0.6902 (0.6911)  class_error_unscaled: 16.9014 (16.6288)  loss_bbox_unscaled: 0.0262 (0.0277)  loss_giou_unscaled: 0.3220 (0.3286)  cardinality_error_unscaled: 231.7500 (234.1596)  loss_ce_0_unscaled: 0.7044 (0.7116)  loss_bbox_0_unscaled: 0.0272 (0.0281)  loss_giou_0_unscaled: 0.3337 (0.3294)  cardinality_error_0_unscaled: 266.7500 (265.9840)  loss_ce_1_unscaled: 0.6988 (0.7008)  loss_bbox_1_unscaled: 0.0266 (0.0279)  loss_giou_1_unscaled: 0.3259 (0.3288)  cardinality_error_1_unscaled: 243.5000 (245.9521)  loss_ce_enc_unscaled: 0.7172 (0.7189)  loss_bbox_enc_unscaled: 0.0284 (0.0294)  loss_giou_enc_unscaled: 0.3376 (0.3413)  cardinality_error_enc_unscaled: 257.7500 (257.0053)  time: 1.5227  data: 0.0426
# Test: Total time: 0:01:13 (1.5738 s / it)
# Averaged stats: class_error: 15.15  loss: 6.0551 (6.0443)  loss_ce: 0.6902 (0.6911)  loss_bbox: 0.1312 (0.1385)  loss_giou: 0.6440 (0.6571)  loss_ce_0: 0.7044 (0.7116)  loss_bbox_0: 0.1358 (0.1404)  loss_giou_0: 0.6673 (0.6589)  loss_ce_1: 0.6988 (0.7008)  loss_bbox_1: 0.1332 (0.1396)  loss_giou_1: 0.6517 (0.6576)  loss_ce_enc: 0.7172 (0.7189)  loss_bbox_enc: 0.1422 (0.1471)  loss_giou_enc: 0.6753 (0.6826)  loss_ce_unscaled: 0.6902 (0.6911)  class_error_unscaled: 16.9014 (16.6288)  loss_bbox_unscaled: 0.0262 (0.0277)  loss_giou_unscaled: 0.3220 (0.3286)  cardinality_error_unscaled: 231.7500 (234.1596)  loss_ce_0_unscaled: 0.7044 (0.7116)  loss_bbox_0_unscaled: 0.0272 (0.0281)  loss_giou_0_unscaled: 0.3337 (0.3294)  cardinality_error_0_unscaled: 266.7500 (265.9840)  loss_ce_1_unscaled: 0.6988 (0.7008)  loss_bbox_1_unscaled: 0.0266 (0.0279)  loss_giou_1_unscaled: 0.3259 (0.3288)  cardinality_error_1_unscaled: 243.5000 (245.9521)  loss_ce_enc_unscaled: 0.7172 (0.7189)  loss_bbox_enc_unscaled: 0.0284 (0.0294)  loss_giou_enc_unscaled: 0.3376 (0.3413)  cardinality_error_enc_unscaled: 257.7500 (257.0053)
# Accumulating evaluation results...
# DONE (t=0.37s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.354
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.231
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.684
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.641
# Epoch 0: Train Loss = 7.1029, Val Loss = 6.0397, mAP = 0.0000
# Early stopping: Current mAP (max(regular, EMA)): 0.2150, Best: 0.0000, Diff: 0.2150, Min delta: 0.001
# Grad accum steps:  16
# Total batch size:  64
# LENGTH OF DATA LOADER: 16
# Epoch: [1]  [ 0/16]  eta: 0:36:11  lr: 0.000100  class_error: 21.76  loss: 6.3826 (6.3826)  loss_ce: 0.7419 (0.7419)  loss_bbox: 0.1509 (0.1509)  loss_giou: 0.6802 (0.6802)  loss_ce_0: 0.7684 (0.7684)  loss_bbox_0: 0.1529 (0.1529)  loss_giou_0: 0.6786 (0.6786)  loss_ce_1: 0.7540 (0.7540)  loss_bbox_1: 0.1525 (0.1525)  loss_giou_1: 0.6682 (0.6682)  loss_ce_enc: 0.7727 (0.7727)  loss_bbox_enc: 0.1638 (0.1638)  loss_giou_enc: 0.6987 (0.6987)  loss_ce_unscaled: 0.7419 (0.7419)  class_error_unscaled: 21.7582 (21.7582)  loss_bbox_unscaled: 0.0302 (0.0302)  loss_giou_unscaled: 0.3401 (0.3401)  cardinality_error_unscaled: 3186.7500 (3186.7500)  loss_ce_0_unscaled: 0.7684 (0.7684)  loss_bbox_0_unscaled: 0.0306 (0.0306)  loss_giou_0_unscaled: 0.3393 (0.3393)  cardinality_error_0_unscaled: 3613.2500 (3613.2500)  loss_ce_1_unscaled: 0.7540 (0.7540)  loss_bbox_1_unscaled: 0.0305 (0.0305)  loss_giou_1_unscaled: 0.3341 (0.3341)  cardinality_error_1_unscaled: 3363.5000 (3363.5000)  loss_ce_enc_unscaled: 0.7727 (0.7727)  loss_bbox_enc_unscaled: 0.0328 (0.0328)  loss_giou_enc_unscaled: 0.3493 (0.3493)  cardinality_error_enc_unscaled: 3504.2500 (3504.2500)  time: 135.7377  data: 0.9642
# Epoch: [1]  [10/16]  eta: 0:13:13  lr: 0.000100  class_error: 3.37  loss: 5.9947 (5.9591)  loss_ce: 0.6724 (0.6730)  loss_bbox: 0.1388 (0.1333)  loss_giou: 0.6517 (0.6607)  loss_ce_0: 0.7044 (0.6985)  loss_bbox_0: 0.1388 (0.1391)  loss_giou_0: 0.6384 (0.6563)  loss_ce_1: 0.6781 (0.6768)  loss_bbox_1: 0.1357 (0.1342)  loss_giou_1: 0.6532 (0.6546)  loss_ce_enc: 0.7002 (0.6934)  loss_bbox_enc: 0.1488 (0.1514)  loss_giou_enc: 0.6681 (0.6876)  loss_ce_unscaled: 0.6724 (0.6730)  class_error_unscaled: 10.4990 (10.2666)  loss_bbox_unscaled: 0.0278 (0.0267)  loss_giou_unscaled: 0.3259 (0.3304)  cardinality_error_unscaled: 2874.0000 (2934.0682)  loss_ce_0_unscaled: 0.7044 (0.6985)  loss_bbox_0_unscaled: 0.0278 (0.0278)  loss_giou_0_unscaled: 0.3192 (0.3282)  cardinality_error_0_unscaled: 3320.2500 (3352.2273)  loss_ce_1_unscaled: 0.6781 (0.6768)  loss_bbox_1_unscaled: 0.0271 (0.0268)  loss_giou_1_unscaled: 0.3266 (0.3273)  cardinality_error_1_unscaled: 3056.2500 (3020.0227)  loss_ce_enc_unscaled: 0.7002 (0.6934)  loss_bbox_enc_unscaled: 0.0298 (0.0303)  loss_giou_enc_unscaled: 0.3341 (0.3438)  cardinality_error_enc_unscaled: 3218.0000 (3243.4091)  time: 132.3286  data: 0.7864
# Epoch: [1]  [15/16]  eta: 0:02:11  lr: 0.000100  class_error: 4.21  loss: 5.7189 (5.7176)  loss_ce: 0.6286 (0.6466)  loss_bbox: 0.1253 (0.1259)  loss_giou: 0.6268 (0.6334)  loss_ce_0: 0.6613 (0.6748)  loss_bbox_0: 0.1315 (0.1309)  loss_giou_0: 0.6229 (0.6284)  loss_ce_1: 0.6415 (0.6522)  loss_bbox_1: 0.1274 (0.1269)  loss_giou_1: 0.6160 (0.6287)  loss_ce_enc: 0.6570 (0.6686)  loss_bbox_enc: 0.1461 (0.1410)  loss_giou_enc: 0.6408 (0.6601)  loss_ce_unscaled: 0.6286 (0.6466)  class_error_unscaled: 5.9682 (8.2719)  loss_bbox_unscaled: 0.0251 (0.0252)  loss_giou_unscaled: 0.3134 (0.3167)  cardinality_error_unscaled: 3026.0000 (3106.3906)  loss_ce_0_unscaled: 0.6613 (0.6748)  loss_bbox_0_unscaled: 0.0263 (0.0262)  loss_giou_0_unscaled: 0.3115 (0.3142)  cardinality_error_0_unscaled: 3424.0000 (3411.4375)  loss_ce_1_unscaled: 0.6415 (0.6522)  loss_bbox_1_unscaled: 0.0255 (0.0254)  loss_giou_1_unscaled: 0.3080 (0.3143)  cardinality_error_1_unscaled: 3114.2500 (3163.1719)  loss_ce_enc_unscaled: 0.6570 (0.6686)  loss_bbox_enc_unscaled: 0.0292 (0.0282)  loss_giou_enc_unscaled: 0.3204 (0.3300)  cardinality_error_enc_unscaled: 3322.2500 (3306.2344)  time: 131.6438  data: 0.7854
# Epoch: [1] Total time: 0:35:06 (131.6441 s / it)
# Averaged stats: lr: 0.000100  class_error: 4.21  loss: 5.7189 (5.7176)  loss_ce: 0.6286 (0.6466)  loss_bbox: 0.1253 (0.1259)  loss_giou: 0.6268 (0.6334)  loss_ce_0: 0.6613 (0.6748)  loss_bbox_0: 0.1315 (0.1309)  loss_giou_0: 0.6229 (0.6284)  loss_ce_1: 0.6415 (0.6522)  loss_bbox_1: 0.1274 (0.1269)  loss_giou_1: 0.6160 (0.6287)  loss_ce_enc: 0.6570 (0.6686)  loss_bbox_enc: 0.1461 (0.1410)  loss_giou_enc: 0.6408 (0.6601)  loss_ce_unscaled: 0.6286 (0.6466)  class_error_unscaled: 5.9682 (8.2719)  loss_bbox_unscaled: 0.0251 (0.0252)  loss_giou_unscaled: 0.3134 (0.3167)  cardinality_error_unscaled: 3026.0000 (3106.3906)  loss_ce_0_unscaled: 0.6613 (0.6748)  loss_bbox_0_unscaled: 0.0263 (0.0262)  loss_giou_0_unscaled: 0.3115 (0.3142)  cardinality_error_0_unscaled: 3424.0000 (3411.4375)  loss_ce_1_unscaled: 0.6415 (0.6522)  loss_bbox_1_unscaled: 0.0255 (0.0254)  loss_giou_1_unscaled: 0.3080 (0.3143)  cardinality_error_1_unscaled: 3114.2500 (3163.1719)  loss_ce_enc_unscaled: 0.6570 (0.6686)  loss_bbox_enc_unscaled: 0.0292 (0.0282)  loss_giou_enc_unscaled: 0.3204 (0.3300)  cardinality_error_enc_unscaled: 3322.2500 (3306.2344)
# Test:  [ 0/47]  eta: 0:02:04  class_error: 5.33  loss: 5.4327 (5.4327)  loss_ce: 0.5513 (0.5513)  loss_bbox: 0.1087 (0.1087)  loss_giou: 0.6863 (0.6863)  loss_ce_0: 0.5561 (0.5561)  loss_bbox_0: 0.1102 (0.1102)  loss_giou_0: 0.6819 (0.6819)  loss_ce_1: 0.5617 (0.5617)  loss_bbox_1: 0.1023 (0.1023)  loss_giou_1: 0.6819 (0.6819)  loss_ce_enc: 0.5754 (0.5754)  loss_bbox_enc: 0.1260 (0.1260)  loss_giou_enc: 0.6909 (0.6909)  loss_ce_unscaled: 0.5513 (0.5513)  class_error_unscaled: 5.3333 (5.3333)  loss_bbox_unscaled: 0.0217 (0.0217)  loss_giou_unscaled: 0.3431 (0.3431)  cardinality_error_unscaled: 256.2500 (256.2500)  loss_ce_0_unscaled: 0.5561 (0.5561)  loss_bbox_0_unscaled: 0.0220 (0.0220)  loss_giou_0_unscaled: 0.3410 (0.3410)  cardinality_error_0_unscaled: 260.7500 (260.7500)  loss_ce_1_unscaled: 0.5617 (0.5617)  loss_bbox_1_unscaled: 0.0205 (0.0205)  loss_giou_1_unscaled: 0.3409 (0.3409)  cardinality_error_1_unscaled: 257.7500 (257.7500)  loss_ce_enc_unscaled: 0.5754 (0.5754)  loss_bbox_enc_unscaled: 0.0252 (0.0252)  loss_giou_enc_unscaled: 0.3454 (0.3454)  cardinality_error_enc_unscaled: 256.2500 (256.2500)  time: 2.6509  data: 0.0414
# Test:  [10/47]  eta: 0:00:55  class_error: 6.67  loss: 5.4841 (5.4501)  loss_ce: 0.5975 (0.5929)  loss_bbox: 0.1245 (0.1270)  loss_giou: 0.6211 (0.6246)  loss_ce_0: 0.6268 (0.6249)  loss_bbox_0: 0.1261 (0.1304)  loss_giou_0: 0.6244 (0.6144)  loss_ce_1: 0.6069 (0.5994)  loss_bbox_1: 0.1214 (0.1239)  loss_giou_1: 0.6180 (0.6196)  loss_ce_enc: 0.6249 (0.6190)  loss_bbox_enc: 0.1396 (0.1364)  loss_giou_enc: 0.6480 (0.6375)  loss_ce_unscaled: 0.5975 (0.5929)  class_error_unscaled: 3.1250 (3.6576)  loss_bbox_unscaled: 0.0249 (0.0254)  loss_giou_unscaled: 0.3106 (0.3123)  cardinality_error_unscaled: 258.0000 (258.8182)  loss_ce_0_unscaled: 0.6268 (0.6249)  loss_bbox_0_unscaled: 0.0252 (0.0261)  loss_giou_0_unscaled: 0.3122 (0.3072)  cardinality_error_0_unscaled: 260.7500 (260.3864)  loss_ce_1_unscaled: 0.6069 (0.5994)  loss_bbox_1_unscaled: 0.0243 (0.0248)  loss_giou_1_unscaled: 0.3090 (0.3098)  cardinality_error_1_unscaled: 257.7500 (259.3864)  loss_ce_enc_unscaled: 0.6249 (0.6190)  loss_bbox_enc_unscaled: 0.0279 (0.0273)  loss_giou_enc_unscaled: 0.3240 (0.3187)  cardinality_error_enc_unscaled: 253.7500 (253.5909)  time: 1.5123  data: 0.0412
# Test:  [20/47]  eta: 0:00:38  class_error: 3.70  loss: 5.3591 (5.4012)  loss_ce: 0.5981 (0.5957)  loss_bbox: 0.1201 (0.1234)  loss_giou: 0.6144 (0.6106)  loss_ce_0: 0.6268 (0.6255)  loss_bbox_0: 0.1238 (0.1280)  loss_giou_0: 0.6031 (0.6080)  loss_ce_1: 0.6069 (0.6023)  loss_bbox_1: 0.1197 (0.1209)  loss_giou_1: 0.6046 (0.6063)  loss_ce_enc: 0.6241 (0.6208)  loss_bbox_enc: 0.1295 (0.1342)  loss_giou_enc: 0.6327 (0.6257)  loss_ce_unscaled: 0.5981 (0.5957)  class_error_unscaled: 4.1096 (4.3376)  loss_bbox_unscaled: 0.0240 (0.0247)  loss_giou_unscaled: 0.3072 (0.3053)  cardinality_error_unscaled: 257.2500 (258.0119)  loss_ce_0_unscaled: 0.6268 (0.6255)  loss_bbox_0_unscaled: 0.0248 (0.0256)  loss_giou_0_unscaled: 0.3015 (0.3040)  cardinality_error_0_unscaled: 257.7500 (259.3810)  loss_ce_1_unscaled: 0.6069 (0.6023)  loss_bbox_1_unscaled: 0.0239 (0.0242)  loss_giou_1_unscaled: 0.3023 (0.3031)  cardinality_error_1_unscaled: 257.0000 (258.1190)  loss_ce_enc_unscaled: 0.6241 (0.6208)  loss_bbox_enc_unscaled: 0.0259 (0.0268)  loss_giou_enc_unscaled: 0.3164 (0.3129)  cardinality_error_enc_unscaled: 250.2500 (252.7262)  time: 1.3709  data: 0.0389
# Test:  [30/47]  eta: 0:00:23  class_error: 0.00  loss: 5.3434 (5.3782)  loss_ce: 0.6015 (0.5997)  loss_bbox: 0.1194 (0.1210)  loss_giou: 0.5874 (0.6021)  loss_ce_0: 0.6268 (0.6262)  loss_bbox_0: 0.1234 (0.1259)  loss_giou_0: 0.5908 (0.6019)  loss_ce_1: 0.6080 (0.6043)  loss_bbox_1: 0.1194 (0.1200)  loss_giou_1: 0.5975 (0.6004)  loss_ce_enc: 0.6304 (0.6250)  loss_bbox_enc: 0.1290 (0.1315)  loss_giou_enc: 0.6031 (0.6201)  loss_ce_unscaled: 0.6015 (0.5997)  class_error_unscaled: 4.2553 (4.2901)  loss_bbox_unscaled: 0.0239 (0.0242)  loss_giou_unscaled: 0.2937 (0.3010)  cardinality_error_unscaled: 257.5000 (258.2258)  loss_ce_0_unscaled: 0.6268 (0.6262)  loss_bbox_0_unscaled: 0.0247 (0.0252)  loss_giou_0_unscaled: 0.2954 (0.3010)  cardinality_error_0_unscaled: 257.7500 (259.0161)  loss_ce_1_unscaled: 0.6080 (0.6043)  loss_bbox_1_unscaled: 0.0239 (0.0240)  loss_giou_1_unscaled: 0.2988 (0.3002)  cardinality_error_1_unscaled: 256.7500 (258.0323)  loss_ce_enc_unscaled: 0.6304 (0.6250)  loss_bbox_enc_unscaled: 0.0258 (0.0263)  loss_giou_enc_unscaled: 0.3016 (0.3101)  cardinality_error_enc_unscaled: 251.0000 (252.4758)  time: 1.3445  data: 0.0372
# Test:  [40/47]  eta: 0:00:09  class_error: 4.76  loss: 5.4089 (5.4135)  loss_ce: 0.6101 (0.6041)  loss_bbox: 0.1203 (0.1216)  loss_giou: 0.5956 (0.6056)  loss_ce_0: 0.6355 (0.6305)  loss_bbox_0: 0.1234 (0.1259)  loss_giou_0: 0.5995 (0.6058)  loss_ce_1: 0.6163 (0.6089)  loss_bbox_1: 0.1203 (0.1208)  loss_giou_1: 0.6011 (0.6041)  loss_ce_enc: 0.6336 (0.6273)  loss_bbox_enc: 0.1282 (0.1327)  loss_giou_enc: 0.6308 (0.6263)  loss_ce_unscaled: 0.6101 (0.6041)  class_error_unscaled: 4.7619 (4.5580)  loss_bbox_unscaled: 0.0241 (0.0243)  loss_giou_unscaled: 0.2978 (0.3028)  cardinality_error_unscaled: 258.2500 (258.0305)  loss_ce_0_unscaled: 0.6355 (0.6305)  loss_bbox_0_unscaled: 0.0247 (0.0252)  loss_giou_0_unscaled: 0.2998 (0.3029)  cardinality_error_0_unscaled: 259.0000 (258.9512)  loss_ce_1_unscaled: 0.6163 (0.6089)  loss_bbox_1_unscaled: 0.0241 (0.0242)  loss_giou_1_unscaled: 0.3006 (0.3020)  cardinality_error_1_unscaled: 256.2500 (257.7561)  loss_ce_enc_unscaled: 0.6336 (0.6273)  loss_bbox_enc_unscaled: 0.0256 (0.0265)  loss_giou_enc_unscaled: 0.3154 (0.3131)  cardinality_error_enc_unscaled: 250.7500 (252.2866)  time: 1.3496  data: 0.0376
# Test:  [46/47]  eta: 0:00:01  class_error: 6.06  loss: 5.4089 (5.4154)  loss_ce: 0.6062 (0.6026)  loss_bbox: 0.1152 (0.1197)  loss_giou: 0.6052 (0.6090)  loss_ce_0: 0.6355 (0.6300)  loss_bbox_0: 0.1186 (0.1241)  loss_giou_0: 0.6042 (0.6091)  loss_ce_1: 0.6124 (0.6081)  loss_bbox_1: 0.1149 (0.1190)  loss_giou_1: 0.6043 (0.6071)  loss_ce_enc: 0.6309 (0.6262)  loss_bbox_enc: 0.1269 (0.1309)  loss_giou_enc: 0.6351 (0.6296)  loss_ce_unscaled: 0.6062 (0.6026)  class_error_unscaled: 4.7619 (4.6386)  loss_bbox_unscaled: 0.0230 (0.0239)  loss_giou_unscaled: 0.3026 (0.3045)  cardinality_error_unscaled: 258.0000 (257.9947)  loss_ce_0_unscaled: 0.6355 (0.6300)  loss_bbox_0_unscaled: 0.0237 (0.0248)  loss_giou_0_unscaled: 0.3021 (0.3045)  cardinality_error_0_unscaled: 259.0000 (258.9309)  loss_ce_1_unscaled: 0.6124 (0.6081)  loss_bbox_1_unscaled: 0.0230 (0.0238)  loss_giou_1_unscaled: 0.3021 (0.3035)  cardinality_error_1_unscaled: 257.0000 (257.7340)  loss_ce_enc_unscaled: 0.6309 (0.6262)  loss_bbox_enc_unscaled: 0.0254 (0.0262)  loss_giou_enc_unscaled: 0.3176 (0.3148)  cardinality_error_enc_unscaled: 251.0000 (252.3457)  time: 1.3127  data: 0.0366
# Test: Total time: 0:01:04 (1.3705 s / it)
# Averaged stats: class_error: 6.06  loss: 5.4089 (5.4154)  loss_ce: 0.6062 (0.6026)  loss_bbox: 0.1152 (0.1197)  loss_giou: 0.6052 (0.6090)  loss_ce_0: 0.6355 (0.6300)  loss_bbox_0: 0.1186 (0.1241)  loss_giou_0: 0.6042 (0.6091)  loss_ce_1: 0.6124 (0.6081)  loss_bbox_1: 0.1149 (0.1190)  loss_giou_1: 0.6043 (0.6071)  loss_ce_enc: 0.6309 (0.6262)  loss_bbox_enc: 0.1269 (0.1309)  loss_giou_enc: 0.6351 (0.6296)  loss_ce_unscaled: 0.6062 (0.6026)  class_error_unscaled: 4.7619 (4.6386)  loss_bbox_unscaled: 0.0230 (0.0239)  loss_giou_unscaled: 0.3026 (0.3045)  cardinality_error_unscaled: 258.0000 (257.9947)  loss_ce_0_unscaled: 0.6355 (0.6300)  loss_bbox_0_unscaled: 0.0237 (0.0248)  loss_giou_0_unscaled: 0.3021 (0.3045)  cardinality_error_0_unscaled: 259.0000 (258.9309)  loss_ce_1_unscaled: 0.6124 (0.6081)  loss_bbox_1_unscaled: 0.0230 (0.0238)  loss_giou_1_unscaled: 0.3021 (0.3035)  cardinality_error_1_unscaled: 257.0000 (257.7340)  loss_ce_enc_unscaled: 0.6309 (0.6262)  loss_bbox_enc_unscaled: 0.0254 (0.0262)  loss_giou_enc_unscaled: 0.3176 (0.3148)  cardinality_error_enc_unscaled: 251.0000 (252.3457)
# Accumulating evaluation results...
# DONE (t=0.28s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.533
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.611
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.399
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.708
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.651
# Test:  [ 0/47]  eta: 0:01:07  class_error: 5.33  loss: 5.4252 (5.4252)  loss_ce: 0.5534 (0.5534)  loss_bbox: 0.1064 (0.1064)  loss_giou: 0.6799 (0.6799)  loss_ce_0: 0.5608 (0.5608)  loss_bbox_0: 0.1098 (0.1098)  loss_giou_0: 0.6810 (0.6810)  loss_ce_1: 0.5666 (0.5666)  loss_bbox_1: 0.1007 (0.1007)  loss_giou_1: 0.6721 (0.6721)  loss_ce_enc: 0.5787 (0.5787)  loss_bbox_enc: 0.1256 (0.1256)  loss_giou_enc: 0.6903 (0.6903)  loss_ce_unscaled: 0.5534 (0.5534)  class_error_unscaled: 5.3333 (5.3333)  loss_bbox_unscaled: 0.0213 (0.0213)  loss_giou_unscaled: 0.3399 (0.3399)  cardinality_error_unscaled: 254.7500 (254.7500)  loss_ce_0_unscaled: 0.5608 (0.5608)  loss_bbox_0_unscaled: 0.0220 (0.0220)  loss_giou_0_unscaled: 0.3405 (0.3405)  cardinality_error_0_unscaled: 259.7500 (259.7500)  loss_ce_1_unscaled: 0.5666 (0.5666)  loss_bbox_1_unscaled: 0.0201 (0.0201)  loss_giou_1_unscaled: 0.3360 (0.3360)  cardinality_error_1_unscaled: 256.7500 (256.7500)  loss_ce_enc_unscaled: 0.5787 (0.5787)  loss_bbox_enc_unscaled: 0.0251 (0.0251)  loss_giou_enc_unscaled: 0.3452 (0.3452)  cardinality_error_enc_unscaled: 255.0000 (255.0000)  time: 1.4410  data: 0.0378
# Test:  [10/47]  eta: 0:00:52  class_error: 6.67  loss: 5.4587 (5.4485)  loss_ce: 0.5908 (0.5925)  loss_bbox: 0.1242 (0.1271)  loss_giou: 0.6213 (0.6244)  loss_ce_0: 0.6276 (0.6233)  loss_bbox_0: 0.1262 (0.1301)  loss_giou_0: 0.6241 (0.6148)  loss_ce_1: 0.6038 (0.6000)  loss_bbox_1: 0.1229 (0.1235)  loss_giou_1: 0.6165 (0.6190)  loss_ce_enc: 0.6258 (0.6195)  loss_bbox_enc: 0.1395 (0.1362)  loss_giou_enc: 0.6462 (0.6381)  loss_ce_unscaled: 0.5908 (0.5925)  class_error_unscaled: 3.1250 (3.7713)  loss_bbox_unscaled: 0.0248 (0.0254)  loss_giou_unscaled: 0.3107 (0.3122)  cardinality_error_unscaled: 256.7500 (258.0000)  loss_ce_0_unscaled: 0.6276 (0.6233)  loss_bbox_0_unscaled: 0.0252 (0.0260)  loss_giou_0_unscaled: 0.3121 (0.3074)  cardinality_error_0_unscaled: 259.7500 (260.0682)  loss_ce_1_unscaled: 0.6038 (0.6000)  loss_bbox_1_unscaled: 0.0246 (0.0247)  loss_giou_1_unscaled: 0.3082 (0.3095)  cardinality_error_1_unscaled: 257.7500 (258.6364)  loss_ce_enc_unscaled: 0.6258 (0.6195)  loss_bbox_enc_unscaled: 0.0279 (0.0272)  loss_giou_enc_unscaled: 0.3231 (0.3190)  cardinality_error_enc_unscaled: 253.0000 (252.8636)  time: 1.4322  data: 0.0363
# Test:  [20/47]  eta: 0:00:39  class_error: 3.70  loss: 5.3585 (5.3996)  loss_ce: 0.5941 (0.5952)  loss_bbox: 0.1191 (0.1230)  loss_giou: 0.6128 (0.6102)  loss_ce_0: 0.6265 (0.6240)  loss_bbox_0: 0.1231 (0.1282)  loss_giou_0: 0.6053 (0.6072)  loss_ce_1: 0.6043 (0.6019)  loss_bbox_1: 0.1196 (0.1214)  loss_giou_1: 0.6052 (0.6084)  loss_ce_enc: 0.6258 (0.6215)  loss_bbox_enc: 0.1282 (0.1326)  loss_giou_enc: 0.6351 (0.6261)  loss_ce_unscaled: 0.5941 (0.5952)  class_error_unscaled: 4.0000 (4.3345)  loss_bbox_unscaled: 0.0238 (0.0246)  loss_giou_unscaled: 0.3064 (0.3051)  cardinality_error_unscaled: 256.2500 (257.3452)  loss_ce_0_unscaled: 0.6265 (0.6240)  loss_bbox_0_unscaled: 0.0246 (0.0256)  loss_giou_0_unscaled: 0.3027 (0.3036)  cardinality_error_0_unscaled: 257.5000 (258.9405)  loss_ce_1_unscaled: 0.6043 (0.6019)  loss_bbox_1_unscaled: 0.0239 (0.0243)  loss_giou_1_unscaled: 0.3026 (0.3042)  cardinality_error_1_unscaled: 256.2500 (257.4405)  loss_ce_enc_unscaled: 0.6258 (0.6215)  loss_bbox_enc_unscaled: 0.0256 (0.0265)  loss_giou_enc_unscaled: 0.3176 (0.3130)  cardinality_error_enc_unscaled: 249.7500 (252.0119)  time: 1.4477  data: 0.0368
# Test:  [30/47]  eta: 0:00:24  class_error: 0.00  loss: 5.3279 (5.3743)  loss_ce: 0.6032 (0.5989)  loss_bbox: 0.1176 (0.1208)  loss_giou: 0.5883 (0.6018)  loss_ce_0: 0.6262 (0.6246)  loss_bbox_0: 0.1220 (0.1253)  loss_giou_0: 0.5915 (0.6007)  loss_ce_1: 0.6057 (0.6042)  loss_bbox_1: 0.1186 (0.1203)  loss_giou_1: 0.5880 (0.6013)  loss_ce_enc: 0.6313 (0.6255)  loss_bbox_enc: 0.1282 (0.1308)  loss_giou_enc: 0.6078 (0.6202)  loss_ce_unscaled: 0.6032 (0.5989)  class_error_unscaled: 4.0541 (4.2367)  loss_bbox_unscaled: 0.0235 (0.0242)  loss_giou_unscaled: 0.2942 (0.3009)  cardinality_error_unscaled: 256.7500 (257.5484)  loss_ce_0_unscaled: 0.6262 (0.6246)  loss_bbox_0_unscaled: 0.0244 (0.0251)  loss_giou_0_unscaled: 0.2958 (0.3003)  cardinality_error_0_unscaled: 257.2500 (258.5242)  loss_ce_1_unscaled: 0.6057 (0.6042)  loss_bbox_1_unscaled: 0.0237 (0.0241)  loss_giou_1_unscaled: 0.2940 (0.3006)  cardinality_error_1_unscaled: 256.2500 (257.3226)  loss_ce_enc_unscaled: 0.6313 (0.6255)  loss_bbox_enc_unscaled: 0.0256 (0.0262)  loss_giou_enc_unscaled: 0.3039 (0.3101)  cardinality_error_enc_unscaled: 250.5000 (251.8145)  time: 1.4546  data: 0.0380
# Test:  [40/47]  eta: 0:00:10  class_error: 4.76  loss: 5.4044 (5.4115)  loss_ce: 0.6067 (0.6028)  loss_bbox: 0.1176 (0.1214)  loss_giou: 0.5982 (0.6066)  loss_ce_0: 0.6308 (0.6283)  loss_bbox_0: 0.1220 (0.1255)  loss_giou_0: 0.6026 (0.6058)  loss_ce_1: 0.6150 (0.6075)  loss_bbox_1: 0.1207 (0.1211)  loss_giou_1: 0.6027 (0.6060)  loss_ce_enc: 0.6346 (0.6270)  loss_bbox_enc: 0.1281 (0.1322)  loss_giou_enc: 0.6338 (0.6274)  loss_ce_unscaled: 0.6067 (0.6028)  class_error_unscaled: 4.2553 (4.5570)  loss_bbox_unscaled: 0.0235 (0.0243)  loss_giou_unscaled: 0.2991 (0.3033)  cardinality_error_unscaled: 257.5000 (257.3537)  loss_ce_0_unscaled: 0.6308 (0.6283)  loss_bbox_0_unscaled: 0.0244 (0.0251)  loss_giou_0_unscaled: 0.3013 (0.3029)  cardinality_error_0_unscaled: 257.5000 (258.4512)  loss_ce_1_unscaled: 0.6150 (0.6075)  loss_bbox_1_unscaled: 0.0241 (0.0242)  loss_giou_1_unscaled: 0.3013 (0.3030)  cardinality_error_1_unscaled: 255.0000 (257.1829)  loss_ce_enc_unscaled: 0.6346 (0.6270)  loss_bbox_enc_unscaled: 0.0256 (0.0264)  loss_giou_enc_unscaled: 0.3169 (0.3137)  cardinality_error_enc_unscaled: 250.5000 (251.6098)  time: 1.4457  data: 0.0395
# Test:  [46/47]  eta: 0:00:01  class_error: 3.03  loss: 5.4044 (5.4140)  loss_ce: 0.6061 (0.6017)  loss_bbox: 0.1141 (0.1195)  loss_giou: 0.6114 (0.6095)  loss_ce_0: 0.6278 (0.6283)  loss_bbox_0: 0.1194 (0.1238)  loss_giou_0: 0.6047 (0.6090)  loss_ce_1: 0.6124 (0.6073)  loss_bbox_1: 0.1140 (0.1192)  loss_giou_1: 0.6048 (0.6087)  loss_ce_enc: 0.6275 (0.6260)  loss_bbox_enc: 0.1263 (0.1304)  loss_giou_enc: 0.6348 (0.6305)  loss_ce_unscaled: 0.6061 (0.6017)  class_error_unscaled: 4.2553 (4.5420)  loss_bbox_unscaled: 0.0228 (0.0239)  loss_giou_unscaled: 0.3057 (0.3047)  cardinality_error_unscaled: 257.5000 (257.3404)  loss_ce_0_unscaled: 0.6278 (0.6283)  loss_bbox_0_unscaled: 0.0239 (0.0248)  loss_giou_0_unscaled: 0.3024 (0.3045)  cardinality_error_0_unscaled: 258.0000 (258.4309)  loss_ce_1_unscaled: 0.6124 (0.6073)  loss_bbox_1_unscaled: 0.0228 (0.0238)  loss_giou_1_unscaled: 0.3024 (0.3044)  cardinality_error_1_unscaled: 257.5000 (257.1809)  loss_ce_enc_unscaled: 0.6275 (0.6260)  loss_bbox_enc_unscaled: 0.0253 (0.0261)  loss_giou_enc_unscaled: 0.3174 (0.3153)  cardinality_error_enc_unscaled: 250.5000 (251.6915)  time: 1.4128  data: 0.0385
# Test: Total time: 0:01:07 (1.4314 s / it)
# ...
# Test:  [46/47]  eta: 0:00:01  class_error: 0.00  loss: 4.0329 (4.0735)  loss_ce: 0.4825 (0.4885)  loss_bbox: 0.0786 (0.0811)  loss_giou: 0.4143 (0.4287)  loss_ce_0: 0.4990 (0.5096)  loss_bbox_0: 0.0805 (0.0829)  loss_giou_0: 0.4110 (0.4341)  loss_ce_1: 0.4822 (0.4905)  loss_bbox_1: 0.0793 (0.0811)  loss_giou_1: 0.4110 (0.4296)  loss_ce_enc: 0.4984 (0.5100)  loss_bbox_enc: 0.0839 (0.0893)  loss_giou_enc: 0.4269 (0.4482)  loss_ce_unscaled: 0.4825 (0.4885)  class_error_unscaled: 0.0000 (0.4796)  loss_bbox_unscaled: 0.0157 (0.0162)  loss_giou_unscaled: 0.2071 (0.2144)  cardinality_error_unscaled: 279.5000 (279.8245)  loss_ce_0_unscaled: 0.4990 (0.5096)  loss_bbox_0_unscaled: 0.0161 (0.0166)  loss_giou_0_unscaled: 0.2055 (0.2171)  cardinality_error_0_unscaled: 277.7500 (279.1702)  loss_ce_1_unscaled: 0.4822 (0.4905)  loss_bbox_1_unscaled: 0.0159 (0.0162)  loss_giou_1_unscaled: 0.2055 (0.2148)  cardinality_error_1_unscaled: 278.7500 (279.8511)  loss_ce_enc_unscaled: 0.4984 (0.5100)  loss_bbox_enc_unscaled: 0.0168 (0.0179)  loss_giou_enc_unscaled: 0.2134 (0.2241)  cardinality_error_enc_unscaled: 275.2500 (276.3936)  time: 1.4983  data: 0.0395
# Test: Total time: 0:01:11 (1.5163 s / it)
# Averaged stats: class_error: 0.00  loss: 4.0329 (4.0735)  loss_ce: 0.4825 (0.4885)  loss_bbox: 0.0786 (0.0811)  loss_giou: 0.4143 (0.4287)  loss_ce_0: 0.4990 (0.5096)  loss_bbox_0: 0.0805 (0.0829)  loss_giou_0: 0.4110 (0.4341)  loss_ce_1: 0.4822 (0.4905)  loss_bbox_1: 0.0793 (0.0811)  loss_giou_1: 0.4110 (0.4296)  loss_ce_enc: 0.4984 (0.5100)  loss_bbox_enc: 0.0839 (0.0893)  loss_giou_enc: 0.4269 (0.4482)  loss_ce_unscaled: 0.4825 (0.4885)  class_error_unscaled: 0.0000 (0.4796)  loss_bbox_unscaled: 0.0157 (0.0162)  loss_giou_unscaled: 0.2071 (0.2144)  cardinality_error_unscaled: 279.5000 (279.8245)  loss_ce_0_unscaled: 0.4990 (0.5096)  loss_bbox_0_unscaled: 0.0161 (0.0166)  loss_giou_0_unscaled: 0.2055 (0.2171)  cardinality_error_0_unscaled: 277.7500 (279.1702)  loss_ce_1_unscaled: 0.4822 (0.4905)  loss_bbox_1_unscaled: 0.0159 (0.0162)  loss_giou_1_unscaled: 0.2055 (0.2148)  cardinality_error_1_unscaled: 278.7500 (279.8511)  loss_ce_enc_unscaled: 0.4984 (0.5100)  loss_bbox_enc_unscaled: 0.0168 (0.0179)  loss_giou_enc_unscaled: 0.2134 (0.2241)  cardinality_error_enc_unscaled: 275.2500 (276.3936)
# Accumulating evaluation results...
# DONE (t=0.40s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.537
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.867
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.553
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.742
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.657
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.485
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.781
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.670
# Epoch 49: Train Loss = 3.4327, Val Loss = 4.1357, mAP = 0.0000
# Early stopping: Current mAP (max(regular, EMA)): 0.5370, Best: 0.5372, Diff: -0.0002, Min delta: 0.001
# Early stopping: No improvement in mAP for 2 epochs (best: 0.5372, current: 0.5370)
# Training time 1 day, 8:29:41
# Results saved to D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\basketball_output\results.json
# Test:  [ 0/43]  eta: 0:01:09  class_error: 0.00  loss: 4.1183 (4.1183)  loss_ce: 0.4844 (0.4844)  loss_bbox: 0.0806 (0.0806)  loss_giou: 0.4550 (0.4550)  loss_ce_0: 0.4942 (0.4942)  loss_bbox_0: 0.0814 (0.0814)  loss_giou_0: 0.4597 (0.4597)  loss_ce_1: 0.4831 (0.4831)  loss_bbox_1: 0.0805 (0.0805)  loss_giou_1: 0.4570 (0.4570)  loss_ce_enc: 0.5101 (0.5101)  loss_bbox_enc: 0.0820 (0.0820)  loss_giou_enc: 0.4503 (0.4503)  loss_ce_unscaled: 0.4844 (0.4844)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0161 (0.0161)  loss_giou_unscaled: 0.2275 (0.2275)  cardinality_error_unscaled: 279.0000 (279.0000)  loss_ce_0_unscaled: 0.4942 (0.4942)  loss_bbox_0_unscaled: 0.0163 (0.0163)  loss_giou_0_unscaled: 0.2299 (0.2299)  cardinality_error_0_unscaled: 278.5000 (278.5000)  loss_ce_1_unscaled: 0.4831 (0.4831)  loss_bbox_1_unscaled: 0.0161 (0.0161)  loss_giou_1_unscaled: 0.2285 (0.2285)  cardinality_error_1_unscaled: 279.0000 (279.0000)  loss_ce_enc_unscaled: 0.5101 (0.5101)  loss_bbox_enc_unscaled: 0.0164 (0.0164)  loss_giou_enc_unscaled: 0.2252 (0.2252)  cardinality_error_enc_unscaled: 275.5000 (275.5000)  time: 1.6267  data: 0.0684
# Test:  [10/43]  eta: 0:00:50  class_error: 0.00  loss: 3.7515 (3.9049)  loss_ce: 0.4664 (0.4706)  loss_bbox: 0.0678 (0.0687)  loss_giou: 0.4083 (0.4172)  loss_ce_0: 0.4789 (0.4897)  loss_bbox_0: 0.0714 (0.0696)  loss_giou_0: 0.4043 (0.4231)  loss_ce_1: 0.4663 (0.4733)  loss_bbox_1: 0.0683 (0.0684)  loss_giou_1: 0.3938 (0.4188)  loss_ce_enc: 0.4927 (0.4962)  loss_bbox_enc: 0.0735 (0.0746)  loss_giou_enc: 0.4229 (0.4347)  loss_ce_unscaled: 0.4664 (0.4706)  class_error_unscaled: 0.0000 (0.5633)  loss_bbox_unscaled: 0.0136 (0.0137)  loss_giou_unscaled: 0.2041 (0.2086)  cardinality_error_unscaled: 277.2500 (277.8864)  loss_ce_0_unscaled: 0.4789 (0.4897)  loss_bbox_0_unscaled: 0.0143 (0.0139)  loss_giou_0_unscaled: 0.2022 (0.2116)  cardinality_error_0_unscaled: 276.5000 (277.5227)  loss_ce_1_unscaled: 0.4663 (0.4733)  loss_bbox_1_unscaled: 0.0137 (0.0137)  loss_giou_1_unscaled: 0.1969 (0.2094)  cardinality_error_1_unscaled: 277.2500 (278.1136)  loss_ce_enc_unscaled: 0.4927 (0.4962)  loss_bbox_enc_unscaled: 0.0147 (0.0149)  loss_giou_enc_unscaled: 0.2114 (0.2173)  cardinality_error_enc_unscaled: 274.0000 (274.3409)  time: 1.5239  data: 0.0511
# Test:  [20/43]  eta: 0:00:34  class_error: 0.00  loss: 3.7515 (3.9029)  loss_ce: 0.4664 (0.4722)  loss_bbox: 0.0713 (0.0719)  loss_giou: 0.3972 (0.4111)  loss_ce_0: 0.4838 (0.4915)  loss_bbox_0: 0.0720 (0.0733)  loss_giou_0: 0.3956 (0.4161)  loss_ce_1: 0.4663 (0.4758)  loss_bbox_1: 0.0711 (0.0721)  loss_giou_1: 0.3921 (0.4129)  loss_ce_enc: 0.4889 (0.4984)  loss_bbox_enc: 0.0767 (0.0788)  loss_giou_enc: 0.4093 (0.4289)  loss_ce_unscaled: 0.4664 (0.4722)  class_error_unscaled: 0.0000 (0.2951)  loss_bbox_unscaled: 0.0143 (0.0144)  loss_giou_unscaled: 0.1986 (0.2055)  cardinality_error_unscaled: 278.2500 (278.3929)  loss_ce_0_unscaled: 0.4838 (0.4915)  loss_bbox_0_unscaled: 0.0144 (0.0147)  loss_giou_0_unscaled: 0.1978 (0.2080)  cardinality_error_0_unscaled: 277.2500 (277.8214)  loss_ce_1_unscaled: 0.4663 (0.4758)  loss_bbox_1_unscaled: 0.0142 (0.0144)  loss_giou_1_unscaled: 0.1961 (0.2064)  cardinality_error_1_unscaled: 277.5000 (278.5000)  loss_ce_enc_unscaled: 0.4889 (0.4984)  loss_bbox_enc_unscaled: 0.0153 (0.0158)  loss_giou_enc_unscaled: 0.2046 (0.2144)  cardinality_error_enc_unscaled: 274.2500 (274.5952)  time: 1.5082  data: 0.0488
# Test:  [30/43]  eta: 0:00:19  class_error: 0.00  loss: 3.9851 (3.9273)  loss_ce: 0.4689 (0.4723)  loss_bbox: 0.0752 (0.0731)  loss_giou: 0.4215 (0.4155)  loss_ce_0: 0.4923 (0.4936)  loss_bbox_0: 0.0767 (0.0740)  loss_giou_0: 0.4240 (0.4208)  loss_ce_1: 0.4755 (0.4757)  loss_bbox_1: 0.0769 (0.0733)  loss_giou_1: 0.4226 (0.4176)  loss_ce_enc: 0.4931 (0.4999)  loss_bbox_enc: 0.0834 (0.0794)  loss_giou_enc: 0.4319 (0.4320)  loss_ce_unscaled: 0.4689 (0.4723)  class_error_unscaled: 0.0000 (0.3327)  loss_bbox_unscaled: 0.0150 (0.0146)  loss_giou_unscaled: 0.2107 (0.2077)  cardinality_error_unscaled: 278.5000 (278.5565)  loss_ce_0_unscaled: 0.4923 (0.4936)  loss_bbox_0_unscaled: 0.0153 (0.0148)  loss_giou_0_unscaled: 0.2120 (0.2104)  cardinality_error_0_unscaled: 278.2500 (277.7903)  loss_ce_1_unscaled: 0.4755 (0.4757)  loss_bbox_1_unscaled: 0.0154 (0.0147)  loss_giou_1_unscaled: 0.2113 (0.2088)  cardinality_error_1_unscaled: 278.7500 (278.5726)  loss_ce_enc_unscaled: 0.4931 (0.4999)  loss_bbox_enc_unscaled: 0.0167 (0.0159)  loss_giou_enc_unscaled: 0.2160 (0.2160)  cardinality_error_enc_unscaled: 274.7500 (274.6210)  time: 1.5137  data: 0.0482
# Test:  [40/43]  eta: 0:00:04  class_error: 0.00  loss: 4.0564 (3.9336)  loss_ce: 0.4745 (0.4743)  loss_bbox: 0.0739 (0.0734)  loss_giou: 0.4215 (0.4147)  loss_ce_0: 0.5003 (0.4966)  loss_bbox_0: 0.0740 (0.0747)  loss_giou_0: 0.4240 (0.4200)  loss_ce_1: 0.4767 (0.4776)  loss_bbox_1: 0.0749 (0.0738)  loss_giou_1: 0.4226 (0.4167)  loss_ce_enc: 0.5021 (0.5017)  loss_bbox_enc: 0.0802 (0.0792)  loss_giou_enc: 0.4319 (0.4309)  loss_ce_unscaled: 0.4745 (0.4743)  class_error_unscaled: 0.0000 (0.2816)  loss_bbox_unscaled: 0.0148 (0.0147)  loss_giou_unscaled: 0.2107 (0.2073)  cardinality_error_unscaled: 278.5000 (278.2256)  loss_ce_0_unscaled: 0.5003 (0.4966)  loss_bbox_0_unscaled: 0.0148 (0.0149)  loss_giou_0_unscaled: 0.2120 (0.2100)  cardinality_error_0_unscaled: 277.5000 (277.5122)  loss_ce_1_unscaled: 0.4767 (0.4776)  loss_bbox_1_unscaled: 0.0150 (0.0148)  loss_giou_1_unscaled: 0.2113 (0.2083)  cardinality_error_1_unscaled: 278.0000 (278.2378)  loss_ce_enc_unscaled: 0.5021 (0.5017)  loss_bbox_enc_unscaled: 0.0160 (0.0158)  loss_giou_enc_unscaled: 0.2160 (0.2155)  cardinality_error_enc_unscaled: 274.0000 (274.1890)  time: 1.5154  data: 0.0484
# Test:  [42/43]  eta: 0:00:01  class_error: 0.00  loss: 4.0564 (3.9279)  loss_ce: 0.4745 (0.4740)  loss_bbox: 0.0748 (0.0732)  loss_giou: 0.4215 (0.4134)  loss_ce_0: 0.5003 (0.4969)  loss_bbox_0: 0.0745 (0.0744)  loss_giou_0: 0.4225 (0.4188)  loss_ce_1: 0.4767 (0.4773)  loss_bbox_1: 0.0749 (0.0736)  loss_giou_1: 0.4244 (0.4156)  loss_ce_enc: 0.5021 (0.5017)  loss_bbox_enc: 0.0815 (0.0790)  loss_giou_enc: 0.4319 (0.4300)  loss_ce_unscaled: 0.4745 (0.4740)  class_error_unscaled: 0.0000 (0.2685)  loss_bbox_unscaled: 0.0150 (0.0146)  loss_giou_unscaled: 0.2107 (0.2067)  cardinality_error_unscaled: 278.0000 (278.1047)  loss_ce_0_unscaled: 0.5003 (0.4969)  loss_bbox_0_unscaled: 0.0149 (0.0149)  loss_giou_0_unscaled: 0.2113 (0.2094)  cardinality_error_0_unscaled: 277.0000 (277.4302)  loss_ce_1_unscaled: 0.4767 (0.4773)  loss_bbox_1_unscaled: 0.0150 (0.0147)  loss_giou_1_unscaled: 0.2122 (0.2078)  cardinality_error_1_unscaled: 277.7500 (278.1395)  loss_ce_enc_unscaled: 0.5021 (0.5017)  loss_bbox_enc_unscaled: 0.0163 (0.0158)  loss_giou_enc_unscaled: 0.2160 (0.2150)  cardinality_error_enc_unscaled: 273.7500 (274.1047)  time: 1.4557  data: 0.0468
# Test: Total time: 0:01:04 (1.4888 s / it)
# Averaged stats: class_error: 0.00  loss: 4.0564 (3.9279)  loss_ce: 0.4745 (0.4740)  loss_bbox: 0.0748 (0.0732)  loss_giou: 0.4215 (0.4134)  loss_ce_0: 0.5003 (0.4969)  loss_bbox_0: 0.0745 (0.0744)  loss_giou_0: 0.4225 (0.4188)  loss_ce_1: 0.4767 (0.4773)  loss_bbox_1: 0.0749 (0.0736)  loss_giou_1: 0.4244 (0.4156)  loss_ce_enc: 0.5021 (0.5017)  loss_bbox_enc: 0.0815 (0.0790)  loss_giou_enc: 0.4319 (0.4300)  loss_ce_unscaled: 0.4745 (0.4740)  class_error_unscaled: 0.0000 (0.2685)  loss_bbox_unscaled: 0.0150 (0.0146)  loss_giou_unscaled: 0.2107 (0.2067)  cardinality_error_unscaled: 278.0000 (278.1047)  loss_ce_0_unscaled: 0.5003 (0.4969)  loss_bbox_0_unscaled: 0.0149 (0.0149)  loss_giou_0_unscaled: 0.2113 (0.2094)  cardinality_error_0_unscaled: 277.0000 (277.4302)  loss_ce_1_unscaled: 0.4767 (0.4773)  loss_bbox_1_unscaled: 0.0150 (0.0147)  loss_giou_1_unscaled: 0.2122 (0.2078)  cardinality_error_1_unscaled: 277.7500 (278.1395)  loss_ce_enc_unscaled: 0.5021 (0.5017)  loss_bbox_enc_unscaled: 0.0163 (0.0158)  loss_giou_enc_unscaled: 0.2160 (0.2150)  cardinality_error_enc_unscaled: 273.7500 (274.1047)
# Accumulating evaluation results...
# DONE (t=0.30s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.896
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.577
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.751
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.861
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.616
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.793
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.887
# Test results: {'class_error': 0.26854599353879, 'loss': 3.9279416494591293, 'loss_ce': 0.47403259817944016, 'loss_bbox': 0.07316151070733402, 'loss_giou': 0.4134358105271362, 'loss_ce_0': 0.4968811363674874, 'loss_bbox_0': 0.07444058124755704, 'loss_giou_0': 0.41883343180944754, 'loss_ce_1': 0.47734213499135747, 'loss_bbox_1': 0.07357670479389124, 'loss_giou_1': 0.4155941584775614, 'loss_ce_enc': 0.5016647376293359, 'loss_bbox_enc': 0.07895506788478342, 'loss_giou_enc': 0.430023742969646, 'loss_ce_unscaled': 0.47403259817944016, 'class_error_unscaled': 0.26854599353879, 'loss_bbox_unscaled': 0.014632302119808142, 'loss_giou_unscaled': 0.2067179052635681, 'cardinality_error_unscaled': 278.1046511627907, 'loss_ce_0_unscaled': 0.4968811363674874, 'loss_bbox_0_unscaled': 0.014888116288497004, 'loss_giou_0_unscaled': 0.20941671590472377, 'cardinality_error_0_unscaled': 277.43023255813955, 'loss_ce_1_unscaled': 0.47734213499135747, 'loss_bbox_1_unscaled': 0.014715340854816659, 'loss_giou_1_unscaled': 0.2077970792387807, 'cardinality_error_1_unscaled': 278.13953488372096, 'loss_ce_enc_unscaled': 0.5016647376293359, 'loss_bbox_enc_unscaled': 0.01579101355529802, 'loss_giou_enc_unscaled': 0.215011871484823, 'cardinality_error_enc_unscaled': 274.1046511627907, 'results_json': {'class_map': [{'class': 'ball', 'map@50:95': 0.36240455785106496, 'map@50': 0.7362935860512544, 'precision': 0.6453488372093024, 'recall': 0.73}, {'class': 'number', 'map@50:95': 0.30306613408733707, 'map@50': 0.7843960147518277, 'precision': 0.8779342723004695, 'recall': 0.73}, {'class': 'player', 'map@50:95': 0.7553725764218218, 'map@50': 0.98767296515866, 'precision': 0.9992537313432835, 'recall': 0.73}, {'class': 'referee', 'map@50:95': 0.746723276937583, 'map@50': 0.9701521678882502, 'precision': 0.9939024390243902, 'recall': 0.73}, {'class': 'rim', 'map@50:95': 0.5790236577840888, 'map@50': 1.0, 'precision': 1.0, 'recall': 0.73}, {'class': 'all', 'map@50:95': 0.549318040616379, 'map@50': 0.8957029467699984, 'precision': 0.9032878559754891, 'recall': 0.73}], 'map': 0.8957029467699984, 'precision': 0.9032878559754891, 'recall': 0.73}, 'coco_eval_bbox': [0.549318040616379, 0.8957029467699984, 0.5773175915043076, 0.29265807750281786, 0.7511845984227296, 0.8605972853288413, 0.31594881675435393, 0.6086950467579625, 0.6163631535191919, 0.4888264228293194, 0.7934937073329308, 0.8873626373626374]}
# Results saved to D:\Ruturaj\New folder (3)\Ruturaj\Smart Systems\rfdetr\RFDETR\basketball_output/metrics_plot.png

# %%
from PIL import Image

Image.open("D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\basketball_output\\metrics_plot.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x1200>

# %%
import gc
import torch
import weakref

def cleanup_gpu_memory(obj=None, verbose: bool = False):

    if not torch.cuda.is_available():
        if verbose:
            print("[INFO] CUDA is not available. No GPU cleanup needed.")
        return

    def get_memory_stats():
        allocated = torch.cuda.memory_allocated()
        reserved = torch.cuda.memory_reserved()
        return allocated, reserved

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[Before] Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

    # Ensure we drop all strong references
    if obj is not None:
        ref = weakref.ref(obj)
        del obj
        if ref() is not None and verbose:
            print("[WARNING] Object not fully garbage collected yet.")

    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[After]  Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

# %%
cleanup_gpu_memory(model, verbose=True)
# Out:
# [INFO] CUDA is not available. No GPU cleanup needed.

# %%
from rfdetr import RFDETRBase

model = RFDETRBase()

DATASET_DIR = "D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\basketball-player-detection-2.v13i.coco"
OUTPUT_DIR = "D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\basketball_output"
# Out:
# Loading pretrain weights

# %%
model = RFDETRBase(pretrain_weights="D:\\Ruturaj\\New folder (3)\\Ruturaj\\Smart Systems\\rfdetr\\RFDETR\\basketball_output\\checkpoint_best_total.pth")
# Out:
# Loading pretrain weights

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{DATASET_DIR}/test",
    annotations_path=f"{DATASET_DIR}/test/_annotations.coco.json",
)

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

model.optimize_for_inference()
targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 169/169 [00:15<00:00, 11.18it/s]

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])
